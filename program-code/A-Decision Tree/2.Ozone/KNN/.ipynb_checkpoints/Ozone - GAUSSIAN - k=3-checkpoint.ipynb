# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from scipy.spatial.distance import euclidean

# %%
df = pd.read_csv("ozone_eightr.csv")

# %%
df
# Out:
#             date  WSR0  WSR1  WSR2  WSR3  WSR4  WSR5  WSR6  WSR7  WSR8  ...  \
# 0       1/1/1998   0.8   1.8   2.4   2.1   2.0   2.1   1.5   1.7   1.9  ...
# 1       1/2/1998   2.8   3.2   3.3   2.7   3.3   3.2   2.9   2.8   3.1  ...
# 2       1/3/1998   2.9   2.8   2.6   2.1   2.2   2.5   2.5   2.7   2.2  ...
# 3       1/4/1998   4.7   3.8   3.7   3.8   2.9   3.1   2.8   2.5   2.4  ...
# 4       1/5/1998   2.6   2.1   1.6   1.4   0.9   1.5   1.2   1.4   1.3  ...
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 2529  12/27/2004   0.3   0.4   0.5   0.5   0.2   0.3   0.4   0.4   1.3  ...
# 2530  12/28/2004   1.0   1.4   1.1   1.7   1.5   1.7   1.8   1.5   2.1  ...
# 2531  12/29/2004   0.8   0.8   1.2   0.9   0.4   0.6   0.8   1.1   1.5  ...
# 2532  12/30/2004   1.3   0.9   1.5   1.2   1.6   1.8   1.1   1.0   1.9  ...
# 2533  12/31/2004   1.5   1.3   1.8   1.4   1.2   1.7   1.6   1.4   1.6  ...
#
#       RH50    U50    V50    HT50     KI     TT      SLP  SLP_  Precp  Class
# 0     0.15  10.67  -1.56  5795.0 -12.10  17.90  10330.0 -55.0   0.00      0
# 1     0.48   8.39   3.84  5805.0  14.05  29.00  10275.0 -55.0   0.00      0
# 2     0.60   6.94   9.80  5790.0  17.90  41.30  10235.0 -40.0   0.00      0
# 3     0.49   8.73  10.54  5775.0  31.15  51.70  10195.0 -40.0   2.08      0
# 4      NaN    NaN    NaN     NaN    NaN    NaN      NaN   NaN   0.58      0
# ...    ...    ...    ...     ...    ...    ...      ...   ...    ...    ...
# 2529  0.07   7.93  -4.41  5800.0 -25.60  21.80  10295.0  65.0   0.00      0
# 2530  0.04   5.95  -1.14  5845.0 -19.40  19.10  10310.0  15.0   0.00      0
# 2531  0.06   7.80  -0.64  5845.0  -9.60  35.20  10275.0 -35.0   0.00      0
# 2532  0.25   7.72  -0.89  5845.0 -19.60  34.20  10245.0 -30.0   0.05      0
# 2533  0.54  13.07   9.15  5820.0   1.95  39.35  10220.0 -25.0   0.00      0
#
# [2534 rows x 74 columns]

# %%
df.dtypes
# Out:
# date      object
# WSR0     float64
# WSR1     float64
# WSR2     float64
# WSR3     float64
#           ...
# TT       float64
# SLP      float64
# SLP_     float64
# Precp    float64
# Class      int64
# Length: 74, dtype: object

# %%
df.drop('date', axis=1, inplace=True)

# %%
df
# Out:
#       WSR0  WSR1  WSR2  WSR3  WSR4  WSR5  WSR6  WSR7  WSR8  WSR9  ...  RH50  \
# 0      0.8   1.8   2.4   2.1   2.0   2.1   1.5   1.7   1.9   2.3  ...  0.15
# 1      2.8   3.2   3.3   2.7   3.3   3.2   2.9   2.8   3.1   3.4  ...  0.48
# 2      2.9   2.8   2.6   2.1   2.2   2.5   2.5   2.7   2.2   2.5  ...  0.60
# 3      4.7   3.8   3.7   3.8   2.9   3.1   2.8   2.5   2.4   3.1  ...  0.49
# 4      2.6   2.1   1.6   1.4   0.9   1.5   1.2   1.4   1.3   1.4  ...   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 2529   0.3   0.4   0.5   0.5   0.2   0.3   0.4   0.4   1.3   2.2  ...  0.07
# 2530   1.0   1.4   1.1   1.7   1.5   1.7   1.8   1.5   2.1   2.4  ...  0.04
# 2531   0.8   0.8   1.2   0.9   0.4   0.6   0.8   1.1   1.5   1.5  ...  0.06
# 2532   1.3   0.9   1.5   1.2   1.6   1.8   1.1   1.0   1.9   2.0  ...  0.25
# 2533   1.5   1.3   1.8   1.4   1.2   1.7   1.6   1.4   1.6   3.0  ...  0.54
#
#         U50    V50    HT50     KI     TT      SLP  SLP_  Precp  Class
# 0     10.67  -1.56  5795.0 -12.10  17.90  10330.0 -55.0   0.00      0
# 1      8.39   3.84  5805.0  14.05  29.00  10275.0 -55.0   0.00      0
# 2      6.94   9.80  5790.0  17.90  41.30  10235.0 -40.0   0.00      0
# 3      8.73  10.54  5775.0  31.15  51.70  10195.0 -40.0   2.08      0
# 4       NaN    NaN     NaN    NaN    NaN      NaN   NaN   0.58      0
# ...     ...    ...     ...    ...    ...      ...   ...    ...    ...
# 2529   7.93  -4.41  5800.0 -25.60  21.80  10295.0  65.0   0.00      0
# 2530   5.95  -1.14  5845.0 -19.40  19.10  10310.0  15.0   0.00      0
# 2531   7.80  -0.64  5845.0  -9.60  35.20  10275.0 -35.0   0.00      0
# 2532   7.72  -0.89  5845.0 -19.60  34.20  10245.0 -30.0   0.05      0
# 2533  13.07   9.15  5820.0   1.95  39.35  10220.0 -25.0   0.00      0
#
# [2534 rows x 73 columns]

# %%
df.isnull().sum()
# Out:
# WSR0     299
# WSR1     292
# WSR2     294
# WSR3     292
# WSR4     293
#         ...
# TT       125
# SLP       95
# SLP_     158
# Precp      2
# Class      0
# Length: 73, dtype: int64

# %%
null_counts = df.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase :",null_percentages)
# Out:
# total nilai : 184982
# nilai hilang : 14937
# persentase : 8.074839714134349

# %%
null_counts = df.isnull().sum()
null_percentages = 100 * null_counts / len(df)
null_percentages
# Out:
# WSR0     11.799526
# WSR1     11.523283
# WSR2     11.602210
# WSR3     11.523283
# WSR4     11.562747
#            ...
# TT        4.932912
# SLP       3.749013
# SLP_      6.235201
# Precp     0.078927
# Class     0.000000
# Length: 73, dtype: float64

# %% [markdown]
# # Imputasi

# %%
def jarak(df2,col):
    euc_dist[col] = []
    euc_dist_append =euc_dist[col].append
    for row in range(df2.shape[0]):
        current = df2.index[df2.iloc[:,col] == 0].tolist()
        current = current[0]
        a = df2.iloc[current,col+1:].tolist()
        b = df2.iloc[current,:col].tolist()
        x1 = b+a
        if(row is not current):
            a=df2.iloc[row,col+1:].tolist()
            b=df2.iloc[row,:col].tolist()
            x2=b+a
        else:
            continue
        dist = euclidean(x1,x2)
        euc_dist_append([dist,df2.iloc[row,col]])
#         print(" x1 = ",x1,"\n x2 = ",x2,"\n distance = ",euc_dist[col])

    lst = list(euc_dist[col])
    lst.sort()
    euc_dist[col] = lst
#     print(euc_dist[col])

# %%
def Final(df,col,k):
    terdekat = []
    mean = 0
    std = 0
    diffsquared = 0
    sum_diffsquared = 0
    fuzzy_val = []
    terdekat_append = terdekat.append
    fuzzy_append = fuzzy_val.append
    
    for val in range(k):
        terdekat_append(euc_dist[col][val])
    
    for x,y in terdekat:
        mean += y        
    mean /= len(terdekat)
    
    for x,y in terdekat:
        diffsquared = (y-mean)**2
        sum_diffsquared = diffsquared + sum_diffsquared
    std_dev = ((sum_diffsquared)/len(terdekat))**(1/2)
    print("mean : ",mean)
    print("standar deviasi : ",std_dev)
    
    for x,y in terdekat:
        fuzzy_append((y,gaussian(y,mean,std_dev)))

    print("fuzzy : ",fuzzy_val)
    
    pembilang = 0
    penyebut = 0
    for nilai,bobot in fuzzy_val:
        pembilang += nilai*bobot
        penyebut += bobot
    
    print("pembilang : ", pembilang)
    print("penyebut : ",penyebut)
    tertimbang = pembilang/penyebut
    print("rata-rata tertimbang : ",tertimbang)
    index = dummy.index[dummy.iloc[:,col] == 0].tolist()
    index = index[0]
    dummy.iloc[index,col] = tertimbang

# %%
def gaussian(val, mean, std_dev):
    gaussian_mf = 2.718**((-1 * (val-mean)**2) / (2 * std_dev**2))
    return gaussian_mf

# %%
df2 = df.copy()
dummy = df2.fillna(0)
dummy
# Out:
#       WSR0  WSR1  WSR2  WSR3  WSR4  WSR5  WSR6  WSR7  WSR8  WSR9  ...  RH50  \
# 0      0.8   1.8   2.4   2.1   2.0   2.1   1.5   1.7   1.9   2.3  ...  0.15
# 1      2.8   3.2   3.3   2.7   3.3   3.2   2.9   2.8   3.1   3.4  ...  0.48
# 2      2.9   2.8   2.6   2.1   2.2   2.5   2.5   2.7   2.2   2.5  ...  0.60
# 3      4.7   3.8   3.7   3.8   2.9   3.1   2.8   2.5   2.4   3.1  ...  0.49
# 4      2.6   2.1   1.6   1.4   0.9   1.5   1.2   1.4   1.3   1.4  ...  0.00
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 2529   0.3   0.4   0.5   0.5   0.2   0.3   0.4   0.4   1.3   2.2  ...  0.07
# 2530   1.0   1.4   1.1   1.7   1.5   1.7   1.8   1.5   2.1   2.4  ...  0.04
# 2531   0.8   0.8   1.2   0.9   0.4   0.6   0.8   1.1   1.5   1.5  ...  0.06
# 2532   1.3   0.9   1.5   1.2   1.6   1.8   1.1   1.0   1.9   2.0  ...  0.25
# 2533   1.5   1.3   1.8   1.4   1.2   1.7   1.6   1.4   1.6   3.0  ...  0.54
#
#         U50    V50    HT50     KI     TT      SLP  SLP_  Precp  Class
# 0     10.67  -1.56  5795.0 -12.10  17.90  10330.0 -55.0   0.00      0
# 1      8.39   3.84  5805.0  14.05  29.00  10275.0 -55.0   0.00      0
# 2      6.94   9.80  5790.0  17.90  41.30  10235.0 -40.0   0.00      0
# 3      8.73  10.54  5775.0  31.15  51.70  10195.0 -40.0   2.08      0
# 4      0.00   0.00     0.0   0.00   0.00      0.0   0.0   0.58      0
# ...     ...    ...     ...    ...    ...      ...   ...    ...    ...
# 2529   7.93  -4.41  5800.0 -25.60  21.80  10295.0  65.0   0.00      0
# 2530   5.95  -1.14  5845.0 -19.40  19.10  10310.0  15.0   0.00      0
# 2531   7.80  -0.64  5845.0  -9.60  35.20  10275.0 -35.0   0.00      0
# 2532   7.72  -0.89  5845.0 -19.60  34.20  10245.0 -30.0   0.05      0
# 2533  13.07   9.15  5820.0   1.95  39.35  10220.0 -25.0   0.00      0
#
# [2534 rows x 73 columns]

# %%
euc_dist = {}

# %%
for i in range(dummy.shape[1]):
    current = dummy.index[dummy.iloc[:,i] == 0].tolist()
    for x in current:
        jarak(dummy,i)
        Final(dummy,i,3)
# Out:
# mean :  0.8666666666666667
# standar deviasi :  0.32998316455372223
# fuzzy :  [(1.1, 0.778820970680917), (0.4, 0.3679175864606329), (1.1, 0.778820970680917)]
# pembilang :  1.8605731700822707
# penyebut :  1.9255595278224669
# rata-rata tertimbang :  0.9662506628326955
# mean :  1.6666666666666667
# standar deviasi :  2.0805982045769644
# fuzzy :  [(0.0, 0.7255620937026971), (0.4, 0.8308557704986), (4.6, 0.3701907779414984)]
# pembilang :  2.0352198867303324
# penyebut :  1.9266086421427955
# rata-rata tertimbang :  1.0563743160970867
# mean :  0.39999999999999997
# standar deviasi :  0.08164965809277261
# fuzzy :  [(0.5, 0.47240328690554545), (0.4, 1.0), (0.3, 0.47240328690554595)]
# pembilang :  0.7779226295244366
# penyebut :  1.9448065738110913
# rata-rata tertimbang :  0.4
# mean :  1.0333333333333334
# standar deviasi :  0.6236095644623235
# fuzzy :  [(1.2, 0.9649195174720684), (1.7, 0.5647515815057151), (0.2, 0.4095220349990777)]
# pembilang :  2.199885516526013
# penyebut :  1.939193133976861
# rata-rata tertimbang :  1.1344334290285614
# mean :  1.8999999999999997
# standar deviasi :  1.0614455552060438
# fuzzy :  [(3.4, 0.3684621894863009), (1.2, 0.8045814500741438), (1.1, 0.7527709958213797)]
# pembilang :  3.0463172797459137
# penyebut :  1.9258146353818244
# rata-rata tertimbang :  1.5818330714585784
# mean :  0.4333333333333333
# standar deviasi :  0.1247219128924647
# fuzzy :  [(0.3, 0.5647515815057151), (0.6, 0.40952203499907774), (0.4, 0.9649195174720685)]
# pembilang :  0.8011065024399886
# penyebut :  1.9391931339768615
# rata-rata tertimbang :  0.41311331419428765
# mean :  1.2333333333333334
# standar deviasi :  0.4496912521077347
# fuzzy :  [(0.6, 0.3709620873499544), (1.5, 0.8387807366186285), (1.6, 0.7172124946711443)]
# pembilang :  2.628288348811746
# penyebut :  1.9269553186397275
# rata-rata tertimbang :  1.363959155351408
# mean :  0.4666666666666666
# standar deviasi :  0.5249338582674541
# fuzzy :  [(0.0, 0.6735989880796184), (0.2, 0.8789573711581659), (1.2, 0.37692642270039495)]
# pembilang :  0.6281031814721071
# penyebut :  1.9294827819381792
# rata-rata tertimbang :  0.32552930109133854
# mean :  0.6666666666666666
# standar deviasi :  0.6236095644623235
# fuzzy :  [(0.0, 0.564751581505715), (0.5, 0.9649195174720684), (1.5, 0.40952203499907774)]
# pembilang :  1.096742811234651
# penyebut :  1.939193133976861
# rata-rata tertimbang :  0.5655665709714386
# mean :  0.3
# standar deviasi :  0.21602468994692867
# fuzzy :  [(0.0, 0.38129354811323213), (0.4, 0.8984073017254401), (0.5, 0.6514680055958544)]
# pembilang :  0.6850969234881032
# penyebut :  1.9311688554345268
# rata-rata tertimbang :  0.35475764926519154
# mean :  0.2333333333333333
# standar deviasi :  0.20548046676563259
# fuzzy :  [(0.0, 0.524835712971582), (0.5, 0.4308402315386608), (0.2, 0.9869296383686192)]
# pembilang :  0.41280604344305427
# penyebut :  1.942605582878862
# rata-rata tertimbang :  0.2125012133607135
# mean :  0.2333333333333333
# standar deviasi :  0.16996731711975951
# fuzzy :  [(0.0, 0.3897655050399652), (0.4, 0.6183384098997248), (0.3, 0.9259684638717255)]
# pembilang :  0.5251259031214075
# penyebut :  1.9340723788114156
# rata-rata tertimbang :  0.27151305653003727
# mean :  0.3666666666666667
# standar deviasi :  0.2867441755680875
# fuzzy :  [(0.0, 0.44154170617800437), (0.7, 0.5088481592936229), (0.4, 0.993266714651033)]
# pembilang :  0.7535003973659493
# penyebut :  1.9436565801226604
# rata-rata tertimbang :  0.3876715696959168
# mean :  0.16666666666666666
# standar deviasi :  0.16996731711975951
# fuzzy :  [(0.0, 0.618338409899725), (0.1, 0.9259684638717255), (0.4, 0.38976550503996504)]
# pembilang :  0.2485030484031586
# penyebut :  1.9340723788114156
# rata-rata tertimbang :  0.12848694346996267
# mean :  0.2333333333333333
# standar deviasi :  0.16996731711975951
# fuzzy :  [(0.0, 0.3897655050399652), (0.3, 0.9259684638717255), (0.4, 0.6183384098997248)]
# pembilang :  0.5251259031214075
# penyebut :  1.9340723788114156
# rata-rata tertimbang :  0.27151305653003727
# mean :  0.3666666666666667
# standar deviasi :  0.38586123009300755
# fuzzy :  [(0.0, 0.6367069829311521), (0.2, 0.9109439494183207), (0.9, 0.38476410802459515)]
# pembilang :  0.5284764871057999
# penyebut :  1.9324150403740679
# rata-rata tertimbang :  0.27347980431962476
# mean :  0.2333333333333333
# standar deviasi :  0.3299831645537222
# fuzzy :  [(0.0, 0.778820970680917), (0.7, 0.3679175864606327), (0.0, 0.778820970680917)]
# pembilang :  0.25754231052244286
# penyebut :  1.9255595278224669
# rata-rata tertimbang :  0.13374933716730456
# mean :  0.3445831123891015
# standar deviasi :  0.39651663317840474
# fuzzy :  [(0.0, 0.6855295927495048), (0.13374933716730456, 0.8681891487589359), (0.9, 0.3749602766632064)]
# pembilang :  0.45358397217923985
# penyebut :  1.928679018171647
# rata-rata tertimbang :  0.2351785693242151
# mean :  1.7666666666666668
# standar deviasi :  2.2216110270602183
# fuzzy :  [(0.0, 0.728947461411684), (4.9, 0.36991060734752224), (0.4, 0.8276234899218955)]
# pembilang :  2.1436113719716174
# penyebut :  1.9264815586811017
# rata-rata tertimbang :  1.112707963547373
# mean :  1.0333333333333334
# standar deviasi :  0.8576453553512405
# fuzzy :  [(0.0, 0.48395877163263923), (1.0, 0.999245076400634), (2.1, 0.4614720886846216)]
# pembilang :  1.9683364626383395
# penyebut :  1.9446759367178947
# rata-rata tertimbang :  1.0121668219746565
# mean :  0.13333333333333333
# standar deviasi :  0.1885618083164127
# fuzzy :  [(0.0, 0.778820970680917), (0.0, 0.778820970680917), (0.4, 0.3679175864606327)]
# pembilang :  0.1471670345842531
# penyebut :  1.9255595278224669
# rata-rata tertimbang :  0.07642819266703119
# mean :  0.3
# standar deviasi :  0.42426406871192857
# fuzzy :  [(0.0, 0.778820970680917), (0.9, 0.36791758646063283), (0.0, 0.778820970680917)]
# pembilang :  0.33112582781456956
# penyebut :  1.9255595278224669
# rata-rata tertimbang :  0.17196343350082022
# mean :  0.5333333333333333
# standar deviasi :  0.6847546194724713
# fuzzy :  [(0.0, 0.7383878235196584), (1.5, 0.36922754129746527), (0.1, 0.8185537582017588)]
# pembilang :  0.6356966877663738
# penyebut :  1.9261691230188824
# rata-rata tertimbang :  0.3300316053089083
# mean :  0.7333333333333334
# standar deviasi :  0.8993825042154694
# fuzzy :  [(0.0, 0.7172124946711443), (0.2, 0.8387807366186284), (2.0, 0.3709620873499545)]
# pembilang :  0.9096803220236347
# penyebut :  1.926955318639727
# rata-rata tertimbang :  0.4720816892971834
# mean :  0.26666666666666666
# standar deviasi :  0.2494438257849294
# fuzzy :  [(0.0, 0.564751581505715), (0.2, 0.9649195174720684), (0.6, 0.40952203499907786)]
# pembilang :  0.4386971244938604
# penyebut :  1.939193133976861
# rata-rata tertimbang :  0.22622662838857546
# mean :  0.26666666666666666
# standar deviasi :  0.3771236166328254
# fuzzy :  [(0.0, 0.778820970680917), (0.0, 0.778820970680917), (0.8, 0.3679175864606327)]
# pembilang :  0.2943340691685062
# penyebut :  1.9255595278224669
# rata-rata tertimbang :  0.15285638533406237
# mean :  0.2333333333333333
# standar deviasi :  0.3299831645537222
# fuzzy :  [(0.0, 0.778820970680917), (0.0, 0.778820970680917), (0.7, 0.3679175864606327)]
# pembilang :  0.25754231052244286
# penyebut :  1.9255595278224669
# rata-rata tertimbang :  0.13374933716730456
# mean :  0.07791644572243485
# standar deviasi :  0.056791923283280074
# fuzzy :  [(0.0, 0.39022010072174274), (0.13374933716730456, 0.6168029272959852), (0.1, 0.9271921766831234)]
# pembilang :  0.1752162003570035
# penyebut :  1.9342152047008514
# rata-rata tertimbang :  0.09058774842177021
# mean :  0.4000000000000001
# standar deviasi :  0.496655480858378
# fuzzy :  [(0.0, 0.7230400262651471), (0.1, 0.833256703302925), (1.1, 0.3704116739579805)]
# pembilang :  0.49077851168407116
# penyebut :  1.9267084035260527
# rata-rata tertimbang :  0.25472381331077476
# mean :  0.8333333333333334
# standar deviasi :  1.1085526098877259
# fuzzy :  [(0.0, 0.75388123790523), (2.4, 0.36841685724583273), (0.1, 0.8034953964823135)]
# pembilang :  0.9645499970382299
# penyebut :  1.9257934916333763
# rata-rata tertimbang :  0.5008584779358349
# mean :  1.2666666666666666
# standar deviasi :  1.1585431464655178
# fuzzy :  [(0.0, 0.5501192814145703), (1.0, 0.9738603926751792), (2.8, 0.4165549034722619)]
# pembilang :  2.1402141223975124
# penyebut :  1.9405345775620115
# rata-rata tertimbang :  1.1028992459832219
# mean :  0.8666666666666667
# standar deviasi :  0.6128258770283412
# fuzzy :  [(0.0, 0.3679175864606329), (1.3, 0.778820970680917), (1.3, 0.778820970680917)]
# pembilang :  2.0249345237703844
# penyebut :  1.9255595278224669
# rata-rata tertimbang :  1.0516083738321487
# mean :  0.3
# standar deviasi :  0.21602468994692867
# fuzzy :  [(0.0, 0.38129354811323213), (0.5, 0.6514680055958544), (0.4, 0.8984073017254401)]
# pembilang :  0.6850969234881032
# penyebut :  1.9311688554345265
# rata-rata tertimbang :  0.3547576492651916
# mean :  0.6
# standar deviasi :  0.648074069840786
# fuzzy :  [(0.0, 0.6514680055958545), (0.3, 0.8984073017254403), (1.5, 0.381293548113232)]
# pembilang :  0.8414625126874801
# penyebut :  1.9311688554345268
# rata-rata tertimbang :  0.4357270522044252
# mean :  0.5
# standar deviasi :  0.5715476066494083
# fuzzy :  [(0.0, 0.6820765485778447), (1.3, 0.37550245551847194), (0.2, 0.8713244932332572)]
# pembilang :  0.6624180908206649
# penyebut :  1.928903497329574
# rata-rata tertimbang :  0.3434169162623918
# mean :  0.6333333333333333
# standar deviasi :  0.4496912521077347
# fuzzy :  [(0.0, 0.3709620873499545), (0.9, 0.8387807366186284), (1.0, 0.7172124946711443)]
# pembilang :  1.47211515762791
# penyebut :  1.9269553186397275
# rata-rata tertimbang :  0.7639591553514082
# mean :  0.23770443806476252
# standar deviasi :  0.17431046128248168
# fuzzy :  [(0.0, 0.394663799375783), (0.41311331419428765, 0.6027403076193196), (0.3, 0.9381413822873842)]
# pembilang :  0.5304424607653169
# penyebut :  1.9355454892824868
# rata-rata tertimbang :  0.2740532132685518
# mean :  0.7333333333333334
# standar deviasi :  0.5249338582674541
# fuzzy :  [(0.0, 0.37692642270039495), (1.2, 0.6735989880796185), (1.0, 0.8789573711581659)]
# pembilang :  1.687276156853708
# penyebut :  1.9294827819381792
# rata-rata tertimbang :  0.8744706989086615
# mean :  1.0707222739915523
# standar deviasi :  0.8991001263191537
# fuzzy :  [(0.0, 0.49212299599176496), (2.2, 0.45443638322643837), (1.0121668219746565, 0.9978817210725092)]
# pembilang :  2.0097828134227265
# penyebut :  1.9444411002907125
# rata-rata tertimbang :  1.0336043674052378
# mean :  0.9
# standar deviasi :  0.648074069840786
# fuzzy :  [(0.0, 0.381293548113232), (1.5, 0.6514680055958545), (1.2, 0.8984073017254403)]
# pembilang :  2.05529077046431
# penyebut :  1.9311688554345268
# rata-rata tertimbang :  1.0642729477955748
# mean :  0.5
# standar deviasi :  0.5715476066494083
# fuzzy :  [(0.0, 0.6820765485778447), (1.3, 0.37550245551847194), (0.2, 0.8713244932332572)]
# pembilang :  0.6624180908206649
# penyebut :  1.928903497329574
# rata-rata tertimbang :  0.3434169162623918
# mean :  0.3333333333333333
# standar deviasi :  0.24944382578492943
# fuzzy :  [(0.0, 0.4095220349990779), (0.6, 0.564751581505715), (0.4, 0.9649195174720683)]
# pembilang :  0.7248187558922563
# penyebut :  1.939193133976861
# rata-rata tertimbang :  0.37377337161142454
# mean :  0.16666666666666666
# standar deviasi :  0.16996731711975951
# fuzzy :  [(0.0, 0.618338409899725), (0.1, 0.9259684638717255), (0.4, 0.38976550503996504)]
# pembilang :  0.2485030484031586
# penyebut :  1.9340723788114156
# rata-rata tertimbang :  0.12848694346996267
# mean :  0.06666666666666667
# standar deviasi :  0.09428090415820635
# fuzzy :  [(0.0, 0.778820970680917), (0.0, 0.778820970680917), (0.2, 0.3679175864606327)]
# pembilang :  0.07358351729212655
# penyebut :  1.9255595278224669
# rata-rata tertimbang :  0.03821409633351559
# mean :  0.6
# standar deviasi :  0.45460605656619524
# fuzzy :  [(0.0, 0.4185841071858162), (1.1, 0.5461967624232023), (0.7, 0.9760992180510439)]
# pembilang :  1.2840858913012532
# penyebut :  1.9408800876600623
# rata-rata tertimbang :  0.6615998069460105
# mean :  0.6
# standar deviasi :  0.43204937989385733
# fuzzy :  [(0.0, 0.38129354811323213), (0.8, 0.8984073017254401), (1.0, 0.6514680055958544)]
# pembilang :  1.3701938469762065
# penyebut :  1.9311688554345268
# rata-rata tertimbang :  0.7095152985303831
# mean :  0.5127380321111719
# standar deviasi :  0.6982739310707214
# fuzzy :  [(0.0, 0.7637112212129241), (0.03821409633351559, 0.7938333492877218), (1.5, 0.3681012649004637)]
# pembilang :  0.5824875214331339
# penyebut :  1.9256458354011095
# rata-rata tertimbang :  0.3024894353492591
# mean :  0.8333333333333334
# standar deviasi :  0.590668171555645
# fuzzy :  [(0.0, 0.3696791761497558), (1.2, 0.8247663195072013), (1.3, 0.731930620120567)]
# pembilang :  1.9412293895653785
# penyebut :  1.9263761157775239
# rata-rata tertimbang :  1.0077104744323824
# mean :  1.2
# standar deviasi :  0.9797958971132712
# fuzzy :  [(0.0, 0.47240328690554567), (2.4, 0.47240328690554567), (1.2, 1.0)]
# pembilang :  2.3337678885733095
# penyebut :  1.9448065738110913
# rata-rata tertimbang :  1.2
# mean :  0.44739947576118827
# standar deviasi :  0.42146714513110534
# fuzzy :  [(0.0, 0.5692912087566835), (0.3300316053089083, 0.9619719226522144), (1.0121668219746565, 0.4075012523409847)]
# pembilang :  0.7299403854276744
# penyebut :  1.9387643837498827
# rata-rata tertimbang :  0.37649772790639574
# mean :  0.3666666666666667
# standar deviasi :  0.26246692913372704
# fuzzy :  [(0.0, 0.37692642270039495), (0.6, 0.6735989880796185), (0.5, 0.8789573711581659)]
# pembilang :  0.843638078426854
# penyebut :  1.9294827819381792
# rata-rata tertimbang :  0.43723534945433074
# mean :  0.10000000000000002
# standar deviasi :  0.08164965809277261
# fuzzy :  [(0.0, 0.4724032869055456), (0.2, 0.4724032869055458), (0.1, 1.0)]
# pembilang :  0.19448065738110917
# penyebut :  1.9448065738110913
# rata-rata tertimbang :  0.10000000000000002
# mean :  1.4666666666666668
# standar deviasi :  1.0498677165349082
# fuzzy :  [(0.0, 0.37692642270039495), (2.4, 0.6735989880796185), (2.0, 0.8789573711581659)]
# pembilang :  3.374552313707416
# penyebut :  1.9294827819381792
# rata-rata tertimbang :  1.748941397817323
# mean :  0.6666666666666666
# standar deviasi :  0.49888765156985887
# fuzzy :  [(0.0, 0.4095220349990779), (1.2, 0.564751581505715), (0.8, 0.9649195174720683)]
# pembilang :  1.4496375117845126
# penyebut :  1.939193133976861
# rata-rata tertimbang :  0.7475467432228491
# mean :  0.8333333333333334
# standar deviasi :  0.7930251502246879
# fuzzy :  [(0.0, 0.5757608501760298), (0.6, 0.9576415547634715), (1.9, 0.4047442683679546)]
# pembilang :  1.3435990427571967
# penyebut :  1.9381466733074557
# rata-rata tertimbang :  0.6932390934398887
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# C:\Users\User\AppData\Local\Temp\ipykernel_7416\2372757207.py:2: RuntimeWarning: invalid value encountered in double_scalars
#   gaussian_mf = 2.718**((-1 * (val-mean)**2) / (2 * std_dev**2))
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(nan, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(nan, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  1.5333333333333332
# standar deviasi :  2.1684607956387456
# fuzzy :  [(0.0, 0.778820970680917), (0.0, 0.778820970680917), (4.6, 0.36791758646063283)]
# pembilang :  1.6924208977189108
# penyebut :  1.9255595278224669
# rata-rata tertimbang :  0.8789242156708588
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  0.0
# standar deviasi :  0.0
# fuzzy :  [(0.0, nan), (0.0, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (0.0, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (nan, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# mean :  nan
# standar deviasi :  nan
# fuzzy :  [(0.0, nan), (nan, nan), (0.0, nan)]
# pembilang :  nan
# penyebut :  nan
# rata-rata tertimbang :  nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\2831359308.py in <module>
#       2     current = dummy.index[dummy.iloc[:,i] == 0].tolist()
#       3     for x in current:
# ----> 4         jarak(dummy,i)
#       5         Final(dummy,i,3)
#
# ~\AppData\Local\Temp\ipykernel_7416\2866411753.py in jarak(df2, col)
#      10         if(row is not current):
#      11             a=df2.iloc[row,col+1:].tolist()
# ---> 12             b=df2.iloc[row,:col].tolist()
#      13             x2=b+a
#      14         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1459     def _getitem_tuple(self, tup: tuple):
#    1460
# -> 1461         tup = self._validate_tuple_indexer(tup)
#    1462         with suppress(IndexingError):
#    1463             return self._getitem_lowerdim(tup)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_tuple_indexer(self, key)
#     767         for i, k in enumerate(key):
#     768             try:
# --> 769                 self._validate_key(k, i)
#     770             except ValueError as err:
#     771                 raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1345
#    1346     def _validate_key(self, key, axis: int):
# -> 1347         if com.is_bool_indexer(key):
#    1348             if hasattr(key, "index") and isinstance(key.index, Index):
#    1349                 if key.index.inferred_type == "integer":
#
# KeyboardInterrupt:

# %%
dummy

# %%
dummy.describe()

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
x = dummy.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)

# %%
classifier = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)

# %%
classifier = KNeighborsClassifier(n_neighbors=7, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)

# %%
classifier = KNeighborsClassifier(n_neighbors=9, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)

# %%
classifier = KNeighborsClassifier(n_neighbors=11, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
