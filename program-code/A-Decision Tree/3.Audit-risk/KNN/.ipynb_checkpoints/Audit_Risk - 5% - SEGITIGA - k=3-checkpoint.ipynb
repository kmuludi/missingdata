# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from scipy.spatial.distance import euclidean

# %%
df = pd.read_csv("audit_risk.csv")

# %%
df
# Out:
#      Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  TOTAL  \
# 0            3.89    4.18      0.6   2.508    2.50      0.2   0.500   6.68
# 1            3.89    0.00      0.2   0.000    4.83      0.2   0.966   4.83
# 2            3.89    0.51      0.2   0.102    0.23      0.2   0.046   0.74
# 3            3.89    0.00      0.2   0.000   10.80      0.6   6.480  10.80
# 4            3.89    0.00      0.2   0.000    0.08      0.2   0.016   0.08
# ..            ...     ...      ...     ...     ...      ...     ...    ...
# 771         55.57    0.49      0.2   0.098    0.40      0.2   0.080   0.89
# 772         55.57    0.47      0.2   0.094    0.37      0.2   0.074   0.84
# 773         55.57    0.24      0.2   0.048    0.04      0.2   0.008   0.28
# 774         55.57    0.20      0.2   0.040    0.00      0.2   0.000   0.20
# 775         55.57    0.00      0.2   0.000    0.00      0.2   0.000   0.00
#
#      numbers  Score_B.1  ...  RiSk_E  History  Prob  Risk_F  Score  \
# 0        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.4
# 1        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 2        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 3        6.0        0.6  ...     0.4      0.0   0.2     0.0    4.4
# 4        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# ..       ...        ...  ...     ...      ...   ...     ...    ...
# 771      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 772      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 773      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 774      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 775      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
#
#      Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0            8.574           0.4             0.5      1.7148   1.0
# 1            2.554           0.4             0.5      0.5108   0.0
# 2            1.548           0.4             0.5      0.3096   0.0
# 3           17.530           0.4             0.5      3.5060   1.0
# 4            1.416           0.4             0.5      0.2832   0.0
# ..             ...           ...             ...         ...   ...
# 771          1.578           0.4             0.5      0.3156   0.0
# 772          1.568           0.4             0.5      0.3136   0.0
# 773          1.456           0.4             0.5      0.2912   0.0
# 774          1.440           0.4             0.5      0.2880   0.0
# 775          1.464           0.4             0.5      0.2928   0.0
#
# [776 rows x 26 columns]

# %%
df.dtypes
# Out:
# Sector_score      float64
# PARA_A            float64
# Score_A           float64
# Risk_A            float64
# PARA_B            float64
# Score_B           float64
# Risk_B            float64
# TOTAL             float64
# numbers           float64
# Score_B.1         float64
# Risk_C            float64
# Money_Value       float64
# Score_MV          float64
# Risk_D            float64
# District_Loss     float64
# PROB              float64
# RiSk_E            float64
# History           float64
# Prob              float64
# Risk_F            float64
# Score             float64
# Inherent_Risk     float64
# CONTROL_RISK      float64
# Detection_Risk    float64
# Audit_Risk        float64
# Risk              float64
# dtype: object

# %%
total_values = df.iloc[:, :-1].size
total_values
# Out:
# 19400

# %%
values_to_drop = int(total_values * 0.05)
values_to_drop
# Out:
# 970

# %%
# Generate random indices for values to be dropped
drop_indices = np.random.choice(total_values, values_to_drop, replace=False)
dataset = df.iloc[:, :-1]

# Replace the selected values with NaN
dataset.values.flat[drop_indices] = np.nan

# %%
df
# Out:
#      Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  TOTAL  \
# 0            3.89    4.18      0.6   2.508    2.50      0.2   0.500   6.68
# 1            3.89    0.00      0.2   0.000    4.83      0.2   0.966    NaN
# 2            3.89    0.51      0.2   0.102    0.23      0.2   0.046   0.74
# 3            3.89    0.00      0.2   0.000   10.80      0.6   6.480  10.80
# 4            3.89    0.00      0.2   0.000    0.08      0.2   0.016   0.08
# ..            ...     ...      ...     ...     ...      ...     ...    ...
# 771         55.57    0.49      0.2   0.098    0.40      0.2   0.080   0.89
# 772         55.57    0.47      0.2   0.094    0.37      NaN   0.074   0.84
# 773         55.57    0.24      0.2   0.048    0.04      0.2   0.008   0.28
# 774         55.57    0.20      0.2   0.040    0.00      0.2   0.000   0.20
# 775           NaN    0.00      0.2   0.000    0.00      0.2   0.000    NaN
#
#      numbers  Score_B.1  ...  RiSk_E  History  Prob  Risk_F  Score  \
# 0        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.4
# 1        5.0        0.2  ...     0.4      0.0   0.2     NaN    2.0
# 2        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 3        6.0        0.6  ...     0.4      0.0   NaN     NaN    4.4
# 4        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# ..       ...        ...  ...     ...      ...   ...     ...    ...
# 771      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 772      5.0        0.2  ...     0.4      0.0   0.2     NaN    2.0
# 773      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 774      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 775      5.0        NaN  ...     0.4      0.0   0.2     0.0    2.0
#
#      Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0            8.574           0.4             0.5      1.7148   1.0
# 1            2.554           0.4             0.5      0.5108   0.0
# 2            1.548           0.4             0.5      0.3096   0.0
# 3           17.530           0.4             0.5      3.5060   1.0
# 4            1.416           0.4             0.5      0.2832   0.0
# ..             ...           ...             ...         ...   ...
# 771          1.578           0.4             0.5      0.3156   0.0
# 772          1.568           0.4             0.5         NaN   0.0
# 773          1.456           0.4             0.5      0.2912   0.0
# 774            NaN           0.4             0.5      0.2880   0.0
# 775          1.464           0.4             0.5      0.2928   0.0
#
# [776 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# Sector_score      29
# PARA_A            37
# Score_A           39
# Risk_A            40
# PARA_B            31
# Score_B           41
# Risk_B            46
# TOTAL             37
# numbers           38
# Score_B.1         43
# Risk_C            41
# Money_Value       46
# Score_MV          31
# Risk_D            36
# District_Loss     47
# PROB              47
# RiSk_E            38
# History           42
# Prob              32
# Risk_F            45
# Score             32
# Inherent_Risk     44
# CONTROL_RISK      31
# Detection_Risk    50
# Audit_Risk        27
# Risk               0
# dtype: int64

# %%
null_counts = df.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("nilai hilang :",null_counts)
print("persentase :",null_percentages)
# Out:
# nilai hilang : 970
# persentase : 4.8076923076923075

# %%
null_counts = df.isnull().sum()
null_percentages = 100 * null_counts / len(df)
null_percentages
# Out:
# Sector_score      3.737113
# PARA_A            4.768041
# Score_A           5.025773
# Risk_A            5.154639
# PARA_B            3.994845
# Score_B           5.283505
# Risk_B            5.927835
# TOTAL             4.768041
# numbers           4.896907
# Score_B.1         5.541237
# Risk_C            5.283505
# Money_Value       5.927835
# Score_MV          3.994845
# Risk_D            4.639175
# District_Loss     6.056701
# PROB              6.056701
# RiSk_E            4.896907
# History           5.412371
# Prob              4.123711
# Risk_F            5.798969
# Score             4.123711
# Inherent_Risk     5.670103
# CONTROL_RISK      3.994845
# Detection_Risk    6.443299
# Audit_Risk        3.479381
# Risk              0.000000
# dtype: float64

# %% [markdown]
# # Imputasi

# %%
def jarak(df2,col):
    euc_dist[col] = []
    euc_dist_append =euc_dist[col].append
    for row in range(df2.shape[0]):
        current = df2.index[df2.iloc[:,col] == 0].tolist()
        current = current[0]
        a = df2.iloc[current,col+1:].tolist()
        b = df2.iloc[current,:col].tolist()
        x1 = b+a
        if(row is not current):
            a=df2.iloc[row,col+1:].tolist()
            b=df2.iloc[row,:col].tolist()
            x2=b+a
        else:
            continue
        dist = euclidean(x1,x2)
        euc_dist_append([dist,df2.iloc[row,col]])
#         print(" x1 = ",x1,"\n x2 = ",x2,"\n distance = ",euc_dist[col])

    lst = list(euc_dist[col])
    lst.sort()
    euc_dist[col] = lst
#     print(euc_dist[col])

# %%
def Final(df,col,k):
    terdekat = []
    mean = 0
    minimum = None
    maximum = None
    fuzzy_val = []
    terdekat_append = terdekat.append
    fuzzy_append = fuzzy_val.append
    
    for val in range(k):
        terdekat_append(euc_dist[col][val])
    
    for x,y in terdekat:
        if (minimum is None or maximum is None):
            minimum = y
            maximum = y
        elif(y<minimum):
            minimum = y
        elif(y>maximum):
            maximum = y
        mean += y
    mean /= len(terdekat)
    print("min : ",minimum)
    print("max : ",maximum)
    print("mean : ",mean)
    for x,y in terdekat:
        print(f"terdekat = {terdekat[0][1]}")
        fuzzy_append((y,fuzzy_triangular(y,minimum,mean,maximum)))

    print("fuzzy : ",fuzzy_val)
    pembilang = 0
    penyebut = 0
#     y = 1
    for nilai,bobot in fuzzy_val:
        pembilang += nilai*bobot
        penyebut += bobot
        
#         if (penyebut == 0):
#             penyebut = y
            
    print("pembilang : ", pembilang)
    print("penyebut : ",penyebut)
    tertimbang = pembilang/penyebut
    print("rata-rata tertimbang : ",tertimbang)
    index = dummy.index[dummy.iloc[:,col] == 0].tolist()
    index = index[0]
    dummy.iloc[index,col] = tertimbang

# %%
def fuzzy_triangular(val, minimum, mean, maximum):
   if val <= minimum or val >= maximum: 
        return 0.0
   elif minimum < val <= mean:
        return float((val - minimum)/(mean - minimum)) 
   elif mean < val < maximum:
        return float((maximum - val)/(maximum - mean))

# %%
df2 = df.copy()
dummy = df2.fillna(0)
dummy
# Out:
#      Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  TOTAL  \
# 0            3.89    4.18      0.6   2.508    2.50      0.2   0.500   6.68
# 1            3.89    0.00      0.2   0.000    4.83      0.2   0.966   0.00
# 2            3.89    0.51      0.2   0.102    0.23      0.2   0.046   0.74
# 3            3.89    0.00      0.2   0.000   10.80      0.6   6.480  10.80
# 4            3.89    0.00      0.2   0.000    0.08      0.2   0.016   0.08
# ..            ...     ...      ...     ...     ...      ...     ...    ...
# 771         55.57    0.49      0.2   0.098    0.40      0.2   0.080   0.89
# 772         55.57    0.47      0.2   0.094    0.37      0.0   0.074   0.84
# 773         55.57    0.24      0.2   0.048    0.04      0.2   0.008   0.28
# 774         55.57    0.20      0.2   0.040    0.00      0.2   0.000   0.20
# 775          0.00    0.00      0.2   0.000    0.00      0.2   0.000   0.00
#
#      numbers  Score_B.1  ...  RiSk_E  History  Prob  Risk_F  Score  \
# 0        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.4
# 1        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 2        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 3        6.0        0.6  ...     0.4      0.0   0.0     0.0    4.4
# 4        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# ..       ...        ...  ...     ...      ...   ...     ...    ...
# 771      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 772      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 773      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 774      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 775      5.0        0.0  ...     0.4      0.0   0.2     0.0    2.0
#
#      Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0            8.574           0.4             0.5      1.7148   1.0
# 1            2.554           0.4             0.5      0.5108   0.0
# 2            1.548           0.4             0.5      0.3096   0.0
# 3           17.530           0.4             0.5      3.5060   1.0
# 4            1.416           0.4             0.5      0.2832   0.0
# ..             ...           ...             ...         ...   ...
# 771          1.578           0.4             0.5      0.3156   0.0
# 772          1.568           0.4             0.5      0.0000   0.0
# 773          1.456           0.4             0.5      0.2912   0.0
# 774          0.000           0.4             0.5      0.2880   0.0
# 775          1.464           0.4             0.5      0.2928   0.0
#
# [776 rows x 26 columns]

# %%
euc_dist = {}

# %%
for i in range(dummy.shape[1]):
    current = dummy.index[dummy.iloc[:,i] == 0].tolist()
    for x in current:
        jarak(dummy,i)
        Final(dummy,i,3)
# Out:
# min :  0.0
# max :  1.85
# mean :  nan
# terdekat = 0.0
# terdekat = 0.0
# terdekat = 0.0
# fuzzy :  [(0.0, 0.0), (1.85, 0.0), (nan, None)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9644\2831359308.py in <module>
#       3     for x in current:
#       4         jarak(dummy,i)
# ----> 5         Final(dummy,i,3)
#
# ~\AppData\Local\Temp\ipykernel_9644\2550585514.py in Final(df, col, k)
#      33 #     y = 1
#      34     for nilai,bobot in fuzzy_val:
# ---> 35         pembilang += nilai*bobot
#      36         penyebut += bobot
#      37
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
dummy

# %%
dummy.describe()

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
x = dummy.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)

# %%
classifier = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)

# %%
classifier = KNeighborsClassifier(n_neighbors=7, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)

# %%
classifier = KNeighborsClassifier(n_neighbors=9, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)

# %%
classifier = KNeighborsClassifier(n_neighbors=11, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
