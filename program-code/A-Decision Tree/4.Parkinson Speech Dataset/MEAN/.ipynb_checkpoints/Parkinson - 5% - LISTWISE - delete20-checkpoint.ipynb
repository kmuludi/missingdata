# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Parkinson_5%.csv")

# %%
df
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0          0.90           0.79
# 1               0.73                       0.0          0.35           0.38
# 2               1.22                       0.0          0.73            NaN
# 3               2.50                       0.0          1.16           1.63
# 4               3.51                       0.0          1.72           1.54
# ...              ...                       ...           ...            ...
# 1015            4.32                       0.0          2.77           1.71
# 1016            1.54                       0.0          1.00           0.65
# 1017            2.86                       0.0          1.11           1.15
# 1018            3.88                       NaN          1.80           1.68
# 1019            3.45                       0.0          1.69           2.00
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 0             2.70             8.33                 0.78            4.52
# 1             1.06             5.86                 0.64            2.06
# 2             2.20             8.72                 0.88            4.35
# 3             3.47            13.51                 1.27            5.26
# 4             5.15             9.11                 1.04            3.10
# ...            ...              ...                  ...             ...
# 1015          8.32            13.92                 1.20            8.56
# 1016          3.01            17.45                 1.69           11.17
# 1017          3.32              NaN                 1.06            2.56
# 1018          5.39            11.57                 1.21            3.99
# 1019          5.07             9.54                 1.07            2.86
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 0               4.61             6.80  ...         187.58             160.0
# 1               3.18             7.19  ...         234.51             170.0
# 2               5.17             7.55  ...         211.44            1431.0
# 3               8.77            16.78  ...         220.23              94.0
# 4               4.93            12.82  ...         225.16             117.0
# ...              ...              ...  ...            ...               ...
# 1015            6.04             8.59  ...         165.03             258.0
# 1016            6.85             9.40  ...         158.61             426.0
# 1017             NaN            11.92  ...         163.01              74.0
# 1018            5.69            13.04  ...         162.87              71.0
# 1019            4.82            10.09  ...         158.77              48.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 0                 159.0         0.01                           0.0
# 1                 169.0         0.01                           0.0
# 2                1427.0         0.01                           0.0
# 3                  92.0         0.00                           0.0
# 4                 114.0         0.00                           NaN
# ...                 ...          ...                           ...
# 1015                NaN         0.01                           0.0
# 1016              425.0         0.01                           0.0
# 1017               70.0         0.01                           0.0
# 1018               68.0         0.01                           0.0
# 1019                NaN         0.01                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                    0.00                     0.0
# 1                                    2.25                     0.0
# 2                                   10.66                     1.0
# 3                                    0.00                     0.0
# 4                                   18.18                     1.0
# ...                                   ...                     ...
# 1015                                 2.91                     NaN
# 1016                                 0.35                     0.0
# 1017                                18.06                     2.0
# 1018                                25.33                     2.0
# 1019                                47.83                     NaN
#
#       Degree of voice breaks  UPDRS  class
# 0                       0.00    NaN    1.0
# 1                       0.00   23.0    1.0
# 2                       0.18   23.0    1.0
# 3                       0.00   23.0    1.0
# 4                      13.32   23.0    1.0
# ...                      ...    ...    ...
# 1015                    7.04    1.0    0.0
# 1016                    0.00    1.0    0.0
# 1017                    6.78    1.0    0.0
# 1018                   11.75    NaN    0.0
# 1019                    0.00    1.0    0.0
#
# [1020 rows x 28 columns]

# %%
df.dtypes
# Out:
# Jitter (local)                         float64
# Jitter (local, absolute)               float64
# Jitter (rap)                           float64
# Jitter (ppq5)                          float64
# Jitter (ddp)                           float64
# Shimmer (local)                        float64
# Shimmer (local, dB)                    float64
# Shimmer (apq3)                         float64
# Shimmer (apq5)                         float64
# Shimmer (apq11)                        float64
# Shimmer (dda)                          float64
# AC                                     float64
# NTH                                    float64
# HTN                                    float64
# Median pitch                           float64
# Mean pitch                             float64
# Standard deviation                     float64
# Minimum pitch                          float64
# Maximum pitch                          float64
# Number of pulses                       float64
# Number of periods                      float64
# Mean period                            float64
# Standard deviation of period           float64
# Fraction of locally unvoiced frames    float64
# Number of voice breaks                 float64
# Degree of voice breaks                 float64
# UPDRS                                  float64
# class                                  float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Jitter (local)                         47
# Jitter (local, absolute)               54
# Jitter (rap)                           54
# Jitter (ppq5)                          56
# Jitter (ddp)                           55
# Shimmer (local)                        59
# Shimmer (local, dB)                    40
# Shimmer (apq3)                         57
# Shimmer (apq5)                         51
# Shimmer (apq11)                        60
# Shimmer (dda)                          68
# AC                                     48
# NTH                                    47
# HTN                                    65
# Median pitch                           45
# Mean pitch                             57
# Standard deviation                     50
# Minimum pitch                          39
# Maximum pitch                          50
# Number of pulses                       45
# Number of periods                      56
# Mean period                            42
# Standard deviation of period           43
# Fraction of locally unvoiced frames    62
# Number of voice breaks                 60
# Degree of voice breaks                 57
# UPDRS                                  61
# class                                   0
# dtype: int64

# %%
null_counts = df.isnull().sum()
null_percentages = 100 * null_counts / len(df)
null_percentages
# Out:
# Jitter (local)                         4.607843
# Jitter (local, absolute)               5.294118
# Jitter (rap)                           5.294118
# Jitter (ppq5)                          5.490196
# Jitter (ddp)                           5.392157
# Shimmer (local)                        5.784314
# Shimmer (local, dB)                    3.921569
# Shimmer (apq3)                         5.588235
# Shimmer (apq5)                         5.000000
# Shimmer (apq11)                        5.882353
# Shimmer (dda)                          6.666667
# AC                                     4.705882
# NTH                                    4.607843
# HTN                                    6.372549
# Median pitch                           4.411765
# Mean pitch                             5.588235
# Standard deviation                     4.901961
# Minimum pitch                          3.823529
# Maximum pitch                          4.901961
# Number of pulses                       4.411765
# Number of periods                      5.490196
# Mean period                            4.117647
# Standard deviation of period           4.215686
# Fraction of locally unvoiced frames    6.078431
# Number of voice breaks                 5.882353
# Degree of voice breaks                 5.588235
# UPDRS                                  5.980392
# class                                  0.000000
# dtype: float64

# %%
null_counts = df.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase hilang :",null_percentages)
# Out:
# total nilai : 28560
# nilai hilang : 1428
# persentase hilang : 5.0

# %% [markdown]
# # Hapus Nilai Hilang

# %%
df2 = df.dropna()
df2
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 1               0.73                       0.0          0.35           0.38
# 6               1.58                       0.0          0.77           0.86
# 7               1.92                       0.0          0.93           1.03
# 10              2.29                       0.0          1.08           1.26
# 15              2.52                       0.0          1.16           1.35
# ...              ...                       ...           ...            ...
# 1005            3.31                       0.0          1.42           1.11
# 1006            1.26                       0.0          0.51           0.69
# 1007            2.46                       0.0          1.30           1.45
# 1011            0.61                       0.0          0.31           0.44
# 1012            2.36                       0.0          1.28           1.37
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 1             1.06             5.86                 0.64            2.06
# 6             2.30             9.06                 1.07            3.79
# 7             2.78            10.18                 1.11            3.65
# 10            3.24             8.99                 0.94            3.39
# 15            3.48            14.33                 1.36            5.82
# ...            ...              ...                  ...             ...
# 1005          4.27             8.45                 0.71            4.13
# 1006          1.54             9.92                 0.93            4.03
# 1007          3.91            12.21                 1.25            5.23
# 1011          0.94             7.22                 0.70            2.64
# 1012          3.84            11.74                 1.14            6.31
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 1               3.18             7.19  ...         234.51             170.0
# 6               5.16             7.67  ...         200.64              85.0
# 7               4.61             7.13  ...         201.92              71.0
# 10              5.65            11.25  ...         202.27              95.0
# 15              9.45            18.52  ...         238.61             205.0
# ...              ...              ...  ...            ...               ...
# 1005            5.73             4.97  ...         182.17              27.0
# 1006            5.78             8.23  ...         207.88              86.0
# 1007            8.93            13.06  ...         203.07              80.0
# 1011            3.68             7.44  ...         205.59              64.0
# 1012            8.06             7.99  ...         208.74              78.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 1                 169.0         0.01                           0.0
# 6                  84.0         0.01                           0.0
# 7                  70.0         0.01                           0.0
# 10                 93.0         0.01                           0.0
# 15                203.0         0.00                           0.0
# ...                 ...          ...                           ...
# 1005               25.0         0.01                           0.0
# 1006               85.0         0.01                           0.0
# 1007               78.0         0.01                           0.0
# 1011               63.0         0.01                           0.0
# 1012               76.0         0.01                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 1                                    2.25                     0.0
# 6                                    4.35                     0.0
# 7                                   33.93                     0.0
# 10                                  21.21                     1.0
# 15                                  46.91                     1.0
# ...                                   ...                     ...
# 1005                                48.49                     0.0
# 1006                                 0.00                     0.0
# 1007                                16.67                     1.0
# 1011                                 0.00                     0.0
# 1012                                18.00                     1.0
#
#       Degree of voice breaks  UPDRS  class
# 1                       0.00   23.0    1.0
# 6                       0.00   23.0    1.0
# 7                       0.00   23.0    1.0
# 10                      7.82   23.0    1.0
# 15                     25.69   23.0    1.0
# ...                      ...    ...    ...
# 1005                    0.00    1.0    0.0
# 1006                    0.00    1.0    0.0
# 1007                   14.30    1.0    0.0
# 1011                    0.00    1.0    0.0
# 1012                   15.95    1.0    0.0
#
# [248 rows x 28 columns]

# %%
df2.describe()
# Out:
#        Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# count      248.000000                     248.0    248.000000     248.000000
# mean         2.563589                       0.0      1.151815       1.247581
# std          1.595276                       0.0      0.848656       0.947711
# min          0.200000                       0.0      0.090000       0.110000
# 25%          1.432500                       0.0      0.540000       0.630000
# 50%          2.235000                       0.0      0.965000       1.035000
# 75%          3.340000                       0.0      1.565000       1.595000
# max          9.520000                       0.0      5.750000       7.210000
#
#        Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# count    248.000000       248.000000           248.000000      248.000000
# mean       3.453952        12.482621             1.165282        5.300363
# std        2.545561         5.305089             0.411799        2.613667
# min        0.280000         1.560000             0.140000        0.760000
# 25%        1.630000         9.115000             0.917500        3.605000
# 50%        2.895000        11.970000             1.145000        5.090000
# 75%        4.690000        14.827500             1.370000        6.537500
# max       17.260000        41.140000             2.720000       24.320000
#
#        Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# count      248.000000       248.000000  ...     248.000000        248.000000
# mean         7.636411        12.095685  ...     229.200202        109.568548
# std          4.172718         5.911958  ...     117.180715        162.571851
# min          0.930000         1.250000  ...      87.500000          6.000000
# 25%          4.977500         7.715000  ...     142.627500         42.750000
# 50%          7.020000        11.330000  ...     200.755000         64.000000
# 75%          9.275000        15.185000  ...     257.567500        113.750000
# max         40.340000        42.000000  ...     507.010000       1484.000000
#
#        Number of periods  Mean period  Standard deviation of period  \
# count         248.000000   248.000000                    248.000000
# mean          106.463710     0.007621                      0.000040
# std           162.324358     0.004267                      0.000635
# min             5.000000     0.000000                      0.000000
# 25%            41.000000     0.010000                      0.000000
# 50%            61.000000     0.010000                      0.000000
# 75%           110.000000     0.010000                      0.000000
# max          1483.000000     0.010000                      0.010000
#
#        Fraction of locally unvoiced frames  Number of voice breaks  \
# count                           248.000000              248.000000
# mean                             26.725887                1.056452
# std                              21.202282                1.366472
# min                               0.000000                0.000000
# 25%                               7.252500                0.000000
# 50%                              25.245000                1.000000
# 75%                              42.177500                1.000000
# max                              88.160000                7.000000
#
#        Degree of voice breaks       UPDRS       class
# count              248.000000  248.000000  248.000000
# mean                12.376008   13.620968    0.556452
# std                 14.633296   15.330155    0.497808
# min                  0.000000    1.000000    0.000000
# 25%                  0.000000    1.000000    0.000000
# 50%                  6.610000    5.000000    1.000000
# 75%                 21.592500   24.000000    1.000000
# max                 57.480000   55.000000    1.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
x = df2.iloc[:, :-1].values
y = df2.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=5)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[19  9]
#  [ 9 25]]
# 0.7096774193548387
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[19  9]
#  [ 9 25]]
# 0.7096774193548387
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=7, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[19  9]
#  [10 24]]
# 0.6935483870967742
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=9, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[19  9]
#  [ 9 25]]
# 0.7096774193548387
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
