# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("parkinson_5%.csv")

# %%
df
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0          0.90            NaN
# 1               0.73                       0.0          0.35           0.38
# 2               1.22                       0.0          0.73           0.67
# 3               2.50                       0.0          1.16           1.63
# 4               3.51                       0.0          1.72           1.54
# ...              ...                       ...           ...            ...
# 1035            5.13                       0.0          2.72           2.51
# 1036            1.76                       NaN           NaN           0.69
# 1037            2.91                       0.0          1.14           1.27
# 1038            3.79                       0.0          1.79           1.48
# 1039            1.81                       0.0          0.68           0.84
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 0             2.70             8.33                 0.78            4.52
# 1             1.06             5.86                 0.64             NaN
# 2             2.20             8.72                 0.88            4.35
# 3             3.47            13.51                  NaN            5.26
# 4             5.15             9.11                 1.04            3.10
# ...            ...              ...                  ...             ...
# 1035          8.16             9.85                 0.97            4.59
# 1036          2.43             7.57                 0.74            2.72
# 1037          3.42            15.49                 1.46            6.43
# 1038          5.36            15.70                 1.37            6.37
# 1039          2.04             7.88                 0.78             NaN
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 0               4.61             6.80  ...         187.58             160.0
# 1               3.18             7.19  ...         234.51             170.0
# 2               5.17             7.55  ...         211.44            1431.0
# 3               8.77            16.78  ...         220.23              94.0
# 4               4.93            12.82  ...         225.16             117.0
# ...              ...              ...  ...            ...               ...
# 1035            6.81             8.30  ...         158.59              63.0
# 1036             NaN            11.93  ...         143.80              47.0
# 1037             NaN            14.24  ...         149.64              79.0
# 1038           11.09            18.82  ...         451.37              75.0
# 1039            4.54              NaN  ...            NaN              62.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 0                 159.0         0.01                           0.0
# 1                 169.0         0.01                           NaN
# 2                1427.0         0.01                           0.0
# 3                  92.0         0.00                           0.0
# 4                 114.0         0.00                           0.0
# ...                 ...          ...                           ...
# 1035               60.0         0.01                           0.0
# 1036               44.0         0.01                           0.0
# 1037               77.0         0.01                           NaN
# 1038               70.0         0.01                           0.0
# 1039               60.0         0.01                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                    0.00                     0.0
# 1                                    2.25                     0.0
# 2                                   10.66                     1.0
# 3                                     NaN                     0.0
# 4                                   18.18                     1.0
# ...                                   ...                     ...
# 1035                                24.19                     2.0
# 1036                                46.05                     1.0
# 1037                                20.00                     1.0
# 1038                                  NaN                     3.0
# 1039                                18.18                     1.0
#
#       Degree of voice breaks  features 27  class
# 0                       0.00         23.0    1.0
# 1                       0.00         23.0    1.0
# 2                       0.18         23.0    1.0
# 3                       0.00         23.0    1.0
# 4                      13.32         23.0    1.0
# ...                      ...          ...    ...
# 1035                   15.11          1.0    0.0
# 1036                   25.79          1.0    0.0
# 1037                    4.57          1.0    0.0
# 1038                   19.58          1.0    0.0
# 1039                    3.39          1.0    0.0
#
# [1040 rows x 28 columns]

# %%
df.dtypes
# Out:
# Jitter (local)                         float64
# Jitter (local, absolute)               float64
# Jitter (rap)                           float64
# Jitter (ppq5)                          float64
# Jitter (ddp)                           float64
# Shimmer (local)                        float64
# Shimmer (local, dB)                    float64
# Shimmer (apq3)                         float64
# Shimmer (apq5)                         float64
# Shimmer (apq11)                        float64
# Shimmer (dda)                          float64
# AC                                     float64
# NTH                                    float64
# HTN                                    float64
# Median pitch                           float64
# Mean pitch                             float64
# Standard deviation                     float64
# Minimum pitch                          float64
# Maximum pitch                          float64
# Number of pulses                       float64
# Number of periods                      float64
# Mean period                            float64
# Standard deviation of period           float64
# Fraction of locally unvoiced frames    float64
# Number of voice breaks                 float64
# Degree of voice breaks                 float64
# features 27                            float64
# class                                  float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Jitter (local)                         56
# Jitter (local, absolute)               55
# Jitter (rap)                           60
# Jitter (ppq5)                          52
# Jitter (ddp)                           59
# Shimmer (local)                        37
# Shimmer (local, dB)                    54
# Shimmer (apq3)                         44
# Shimmer (apq5)                         71
# Shimmer (apq11)                        60
# Shimmer (dda)                          51
# AC                                     50
# NTH                                    51
# HTN                                    59
# Median pitch                           54
# Mean pitch                             69
# Standard deviation                     52
# Minimum pitch                          53
# Maximum pitch                          52
# Number of pulses                       57
# Number of periods                      46
# Mean period                            56
# Standard deviation of period           53
# Fraction of locally unvoiced frames    60
# Number of voice breaks                 46
# Degree of voice breaks                 50
# features 27                            49
# class                                   0
# dtype: int64

# %%
null_counts = df.isnull().sum()
null_percentages = 100 * null_counts / len(df)
null_percentages
# Out:
# Jitter (local)                         5.384615
# Jitter (local, absolute)               5.288462
# Jitter (rap)                           5.769231
# Jitter (ppq5)                          5.000000
# Jitter (ddp)                           5.673077
# Shimmer (local)                        3.557692
# Shimmer (local, dB)                    5.192308
# Shimmer (apq3)                         4.230769
# Shimmer (apq5)                         6.826923
# Shimmer (apq11)                        5.769231
# Shimmer (dda)                          4.903846
# AC                                     4.807692
# NTH                                    4.903846
# HTN                                    5.673077
# Median pitch                           5.192308
# Mean pitch                             6.634615
# Standard deviation                     5.000000
# Minimum pitch                          5.096154
# Maximum pitch                          5.000000
# Number of pulses                       5.480769
# Number of periods                      4.423077
# Mean period                            5.384615
# Standard deviation of period           5.096154
# Fraction of locally unvoiced frames    5.769231
# Number of voice breaks                 4.423077
# Degree of voice breaks                 4.807692
# features 27                            4.711538
# class                                  0.000000
# dtype: float64

# %%
null_counts = df.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase hilang :",null_percentages)
# Out:
# total nilai : 29120
# nilai hilang : 1456
# persentase hilang : 5.0

# %% [markdown]
# # Hapus Nilai Hilang

# %%
df2 = df.dropna()
df2
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 2               1.22                       0.0          0.73           0.67
# 4               3.51                       0.0          1.72           1.54
# 7               1.92                       0.0          0.93           1.03
# 8               2.26                       0.0          1.24           1.53
# 11              1.73                       0.0          0.81           1.06
# ...              ...                       ...           ...            ...
# 1011            0.61                       0.0          0.31           0.44
# 1019            3.45                       0.0          1.69           2.00
# 1031            7.04                       0.0          3.07           2.80
# 1033            5.00                       0.0          2.64           2.11
# 1035            5.13                       0.0          2.72           2.51
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 2             2.20             8.72                 0.88            4.35
# 4             5.15             9.11                 1.04            3.10
# 7             2.78            10.18                 1.11            3.65
# 8             3.72             8.04                 0.88            3.45
# 11            2.42             9.78                 0.98            4.10
# ...            ...              ...                  ...             ...
# 1011          0.94             7.22                 0.70            2.64
# 1019          5.07             9.54                 1.07            2.86
# 1031          9.21            19.95                 1.67           10.60
# 1033          7.93            13.25                 1.25            6.80
# 1035          8.16             9.85                 0.97            4.59
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 2               5.17             7.55  ...         211.44            1431.0
# 4               4.93            12.82  ...         225.16             117.0
# 7               4.61             7.13  ...         201.92              71.0
# 8               4.24             7.65  ...         210.52             107.0
# 11              6.37             9.11  ...         201.26              97.0
# ...              ...              ...  ...            ...               ...
# 1011            3.68             7.44  ...         205.59              64.0
# 1019            4.82            10.09  ...         158.77              48.0
# 1031           14.70            22.38  ...         178.37              45.0
# 1033            7.20            10.83  ...         142.99              56.0
# 1035            6.81             8.30  ...         158.59              63.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 2                1427.0         0.01                           0.0
# 4                 114.0         0.00                           0.0
# 7                  70.0         0.01                           0.0
# 8                 104.0         0.01                           0.0
# 11                 95.0         0.01                           0.0
# ...                 ...          ...                           ...
# 1011               63.0         0.01                           0.0
# 1019               47.0         0.01                           0.0
# 1031               42.0         0.01                           0.0
# 1033               52.0         0.01                           0.0
# 1035               60.0         0.01                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 2                                   10.66                     1.0
# 4                                   18.18                     1.0
# 7                                   33.93                     0.0
# 8                                   15.15                     2.0
# 11                                   7.14                     1.0
# ...                                   ...                     ...
# 1011                                 0.00                     0.0
# 1019                                47.83                     0.0
# 1031                                13.51                     1.0
# 1033                                25.81                     1.0
# 1035                                24.19                     2.0
#
#       Degree of voice breaks  features 27  class
# 2                       0.18         23.0    1.0
# 4                      13.32         23.0    1.0
# 7                       0.00         23.0    1.0
# 8                       9.81         23.0    1.0
# 11                      8.45         23.0    1.0
# ...                      ...          ...    ...
# 1011                    0.00          1.0    0.0
# 1019                    0.00          1.0    0.0
# 1031                    8.92          1.0    0.0
# 1033                   13.72          1.0    0.0
# 1035                   15.11          1.0    0.0
#
# [239 rows x 28 columns]

# %%
df2.describe()
# Out:
#        Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# count      239.000000                     239.0    239.000000     239.000000
# mean         2.776569                       0.0      1.318201       1.423013
# std          1.969002                       0.0      1.150492       1.252406
# min          0.200000                       0.0      0.100000       0.110000
# 25%          1.455000                       0.0      0.540000       0.635000
# 50%          2.440000                       0.0      1.030000       1.120000
# 75%          3.520000                       0.0      1.695000       1.820000
# max         13.340000                       0.0      8.020000       9.270000
#
#        Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# count    239.000000       239.000000           239.000000      239.000000
# mean       3.954728        13.195816             1.217741        5.707448
# std        3.451739         5.812972             0.448890        3.038931
# min        0.290000         2.340000             0.260000        1.160000
# 25%        1.625000         9.250000             0.950000        3.510000
# 50%        3.080000        12.520000             1.180000        5.040000
# 75%        5.080000        16.470000             1.490000        7.010000
# max       24.050000        31.490000             2.720000       17.840000
#
#        Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# count      239.000000       239.000000  ...      239.00000        239.000000
# mean         8.077197        12.741674  ...      231.21749        105.129707
# std          4.462643         6.652025  ...      120.44533        171.168586
# min          1.110000         0.830000  ...       87.50000          6.000000
# 25%          4.930000         8.355000  ...      144.04500         40.000000
# 50%          7.150000        11.640000  ...      189.18000         62.000000
# 75%         10.185000        16.350000  ...      261.23500        103.500000
# max         24.100000        41.280000  ...      504.99000       1484.000000
#
#        Number of periods  Mean period  Standard deviation of period  \
# count         239.000000   239.000000                         239.0
# mean          101.506276     0.007741                           0.0
# std           170.685171     0.004191                           0.0
# min             5.000000     0.000000                           0.0
# 25%            39.000000     0.010000                           0.0
# 50%            59.000000     0.010000                           0.0
# 75%            98.500000     0.010000                           0.0
# max          1483.000000     0.010000                           0.0
#
#        Fraction of locally unvoiced frames  Number of voice breaks  \
# count                           239.000000              239.000000
# mean                             29.411506                1.171548
# std                              20.507496                1.760880
# min                               0.000000                0.000000
# 25%                              11.010000                0.000000
# 50%                              30.160000                1.000000
# 75%                              44.065000                2.000000
# max                              85.000000               12.000000
#
#        Degree of voice breaks  features 27      class
# count              239.000000   239.000000  239.00000
# mean                13.269121    12.196653    0.51046
# std                 16.536162    14.784695    0.50094
# min                  0.000000     1.000000    0.00000
# 25%                  0.000000     1.000000    0.00000
# 50%                  4.320000     5.000000    1.00000
# 75%                 24.195000    23.000000    1.00000
# max                 60.300000    55.000000    1.00000
#
# [8 rows x 28 columns]

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
x = df2.iloc[:, :-1].values
y = df2.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=2)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
param_grid = {
    'max_depth': np.arange(3, 10),  # Range kedalaman pohon dari 3 hingga 9
    'max_features': np.arange(1, 5) # Range jumlah fitur yang dipertimbangkan dari 1 hingga 4
}
classifier = DecisionTreeClassifier()
grid_search = GridSearchCV(classifier, param_grid, cv=5, n_jobs=-1)
grid_search.fit(x, y)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Accuracy:", best_score)
# Out:
# Best Parameters: {'max_depth': 8, 'max_features': 4}
# Best Accuracy: 0.8408687943262411
