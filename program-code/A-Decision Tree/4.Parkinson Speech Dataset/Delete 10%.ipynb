# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train_data.csv")

# %%
df
# Out:
#       Subject ID  Jitter (local)  Jitter (local, absolute)  Jitter (rap)  \
# 0            1.0            1.49                       0.0          0.90
# 1            1.0            0.73                       0.0          0.35
# 2            1.0            1.22                       0.0          0.73
# 3            1.0            2.50                       0.0          1.16
# 4            1.0            3.51                       0.0          1.72
# ...          ...             ...                       ...           ...
# 1035        40.0            5.13                       0.0          2.72
# 1036        40.0            1.76                       0.0          0.81
# 1037        40.0            2.91                       0.0          1.14
# 1038        40.0            3.79                       0.0          1.79
# 1039        40.0            1.81                       0.0          0.68
#
#       Jitter (ppq5)  Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  \
# ...

# %%
df.drop('Subject ID', axis=1, inplace=True)
df
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0          0.90           0.79
# 1               0.73                       0.0          0.35           0.38
# 2               1.22                       0.0          0.73           0.67
# 3               2.50                       0.0          1.16           1.63
# 4               3.51                       0.0          1.72           1.54
# ...              ...                       ...           ...            ...
# 1035            5.13                       0.0          2.72           2.51
# 1036            1.76                       0.0          0.81           0.69
# 1037            2.91                       0.0          1.14           1.27
# 1038            3.79                       0.0          1.79           1.48
# 1039            1.81                       0.0          0.68           0.84
#
# ...

# %%
pct_missing = 0.10371
num_missing = int(df.iloc[:, :-1].size * pct_missing)
num_missing
# Out:
# 2912

# %%
df.iloc[:, :-1].size
# Out:
# 28080

# %%
idx = np.random.choice(df.iloc[:, :-1].size, num_missing, replace=False)

# %%
dataset = df.astype(float)
dataset.iloc[:, :-1].values.flat[idx] = np.nan

# %%
dataset
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0           NaN           0.79
# 1               0.73                       0.0          0.35           0.38
# 2               1.22                       0.0          0.73           0.67
# 3               2.50                       0.0          1.16            NaN
# 4                NaN                       0.0          1.72            NaN
# ...              ...                       ...           ...            ...
# 1035            5.13                       0.0          2.72           2.51
# 1036            1.76                       0.0           NaN           0.69
# 1037            2.91                       0.0          1.14           1.27
# 1038            3.79                       0.0          1.79           1.48
# 1039             NaN                       0.0          0.68           0.84
#
# ...

# %%
dataset.dtypes
# Out:
# Jitter (local)                         float64
# Jitter (local, absolute)               float64
# Jitter (rap)                           float64
# Jitter (ppq5)                          float64
# Jitter (ddp)                           float64
# Shimmer (local)                        float64
# Shimmer (local, dB)                    float64
# Shimmer (apq3)                         float64
# Shimmer (apq5)                         float64
# Shimmer (apq11)                        float64
# Shimmer (dda)                          float64
# AC                                     float64
# NTH                                    float64
# HTN                                    float64
# Median pitch                           float64
# Mean pitch                             float64
# Standard deviation                     float64
# Minimum pitch                          float64
# Maximum pitch                          float64
# Number of pulses                       float64
# ...

# %%
dataset.isnull().sum()
# Out:
# Jitter (local)                         110
# Jitter (local, absolute)               119
# Jitter (rap)                           110
# Jitter (ppq5)                          112
# Jitter (ddp)                           112
# Shimmer (local)                        106
# Shimmer (local, dB)                    101
# Shimmer (apq3)                         100
# Shimmer (apq5)                          99
# Shimmer (apq11)                         94
# Shimmer (dda)                          106
# AC                                     110
# NTH                                    110
# HTN                                    111
# Median pitch                           119
# Mean pitch                             112
# Standard deviation                     103
# Minimum pitch                          125
# Maximum pitch                          119
# Number of pulses                       102
# Number of periods                      111
# Mean period                            113
# ...

# %%
null_counts = dataset.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase :",null_percentages)
# Out:
# total nilai : 29120
# nilai hilang : 2912
# persentase : 10.0

# %%
null_counts = dataset.isnull().sum()
null_percentages = 100 * null_counts / len(dataset)
null_percentages
# Out:
# Jitter (local)                         10.576923
# Jitter (local, absolute)               11.442308
# Jitter (rap)                           10.576923
# Jitter (ppq5)                          10.769231
# Jitter (ddp)                           10.769231
# Shimmer (local)                        10.192308
# Shimmer (local, dB)                     9.711538
# Shimmer (apq3)                          9.615385
# Shimmer (apq5)                          9.519231
# Shimmer (apq11)                         9.038462
# Shimmer (dda)                          10.192308
# AC                                     10.576923
# NTH                                    10.576923
# HTN                                    10.673077
# Median pitch                           11.442308
# Mean pitch                             10.769231
# Standard deviation                      9.903846
# Minimum pitch                          12.019231
# Maximum pitch                          11.442308
# ...

# %%
dataset.to_csv('parkinson_10%.csv', index=False)
