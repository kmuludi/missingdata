# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("audit_10%.csv")

# %%
df
# Out:
#      Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  TOTAL  \
# 0            3.89    4.18      0.6   2.508    2.50      NaN   0.500   6.68
# 1            3.89    0.00      NaN   0.000    4.83      NaN   0.966   4.83
# 2            3.89    0.51      0.2   0.102    0.23      0.2   0.046   0.74
# 3            3.89    0.00      0.2   0.000   10.80      0.6   6.480  10.80
# 4            3.89    0.00      0.2   0.000    0.08      0.2   0.016   0.08
# ..            ...     ...      ...     ...     ...      ...     ...    ...
# 771           NaN     NaN      0.2     NaN    0.40      0.2   0.080   0.89
# 772         55.57    0.47      0.2   0.094    0.37      NaN   0.074    NaN
# 773         55.57    0.24      0.2     NaN     NaN      0.2   0.008   0.28
# 774         55.57    0.20      NaN   0.040    0.00      0.2   0.000   0.20
# 775         55.57    0.00      0.2   0.000    0.00      0.2   0.000   0.00
#
#      numbers  Score_B.1  ...  RiSk_E  History  Prob  Risk_F  Score  \
# 0        NaN        0.2  ...     0.4      NaN   0.2     0.0    2.4
# 1        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 2        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 3        6.0        0.6  ...     0.4      0.0   0.2     0.0    4.4
# 4        5.0        0.2  ...     0.4      0.0   NaN     0.0    NaN
# ..       ...        ...  ...     ...      ...   ...     ...    ...
# 771      5.0        0.2  ...     0.4      0.0   0.2     NaN    2.0
# 772      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 773      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 774      5.0        NaN  ...     0.4      NaN   0.2     0.0    2.0
# 775      5.0        NaN  ...     0.4      0.0   0.2     0.0    2.0
#
#      Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0            8.574           0.4             0.5      1.7148   1.0
# 1            2.554           0.4             0.5      0.5108   0.0
# 2            1.548           0.4             0.5      0.3096   0.0
# 3           17.530           0.4             0.5      3.5060   1.0
# 4            1.416           NaN             NaN      0.2832   0.0
# ..             ...           ...             ...         ...   ...
# 771          1.578           0.4             0.5      0.3156   0.0
# 772          1.568           0.4             0.5         NaN   0.0
# 773          1.456           0.4             0.5      0.2912   0.0
# 774            NaN           0.4             0.5      0.2880   0.0
# 775          1.464           0.4             0.5      0.2928   0.0
#
# [776 rows x 26 columns]

# %%
df.dtypes
# Out:
# Sector_score      float64
# PARA_A            float64
# Score_A           float64
# Risk_A            float64
# PARA_B            float64
# Score_B           float64
# Risk_B            float64
# TOTAL             float64
# numbers           float64
# Score_B.1         float64
# Risk_C            float64
# Money_Value       float64
# Score_MV          float64
# Risk_D            float64
# District_Loss     float64
# PROB              float64
# RiSk_E            float64
# History           float64
# Prob              float64
# Risk_F            float64
# Score             float64
# Inherent_Risk     float64
# CONTROL_RISK      float64
# Detection_Risk    float64
# Audit_Risk        float64
# Risk              float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Sector_score      74
# PARA_A            62
# Score_A           76
# Risk_A            87
# PARA_B            77
# Score_B           83
# Risk_B            93
# TOTAL             94
# numbers           88
# Score_B.1         94
# Risk_C            91
# Money_Value       71
# Score_MV          84
# Risk_D            71
# District_Loss     80
# PROB              63
# RiSk_E            93
# History           73
# Prob              89
# Risk_F            80
# Score             75
# Inherent_Risk     71
# CONTROL_RISK      92
# Detection_Risk    75
# Audit_Risk        81
# Risk               0
# dtype: int64

# %%
null_counts = df.isnull().sum()
null_percentages = 100 * null_counts / len(df)
null_percentages
# Out:
# Sector_score       9.536082
# PARA_A             7.989691
# Score_A            9.793814
# Risk_A            11.211340
# PARA_B             9.922680
# Score_B           10.695876
# Risk_B            11.984536
# TOTAL             12.113402
# numbers           11.340206
# Score_B.1         12.113402
# Risk_C            11.726804
# Money_Value        9.149485
# Score_MV          10.824742
# Risk_D             9.149485
# District_Loss     10.309278
# PROB               8.118557
# RiSk_E            11.984536
# History            9.407216
# Prob              11.469072
# Risk_F            10.309278
# Score              9.664948
# Inherent_Risk      9.149485
# CONTROL_RISK      11.855670
# Detection_Risk     9.664948
# Audit_Risk        10.438144
# Risk               0.000000
# dtype: float64

# %%
null_counts = df.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase hilang :",null_percentages)
# Out:
# total nilai : 20176
# nilai hilang : 2017
# persentase hilang : 9.997026169706581

# %% [markdown]
# # Imputasi Median

# %%
df2 = df.fillna(df.median())

# %%
df2
# Out:
#      Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B   TOTAL  \
# 0            3.89    4.18      0.6   2.508    2.50      0.2   0.500   6.680
# 1            3.89    0.00      0.2   0.000    4.83      0.2   0.966   4.830
# 2            3.89    0.51      0.2   0.102    0.23      0.2   0.046   0.740
# 3            3.89    0.00      0.2   0.000   10.80      0.6   6.480  10.800
# 4            3.89    0.00      0.2   0.000    0.08      0.2   0.016   0.080
# ..            ...     ...      ...     ...     ...      ...     ...     ...
# 771          3.89    0.89      0.2   0.180    0.40      0.2   0.080   0.890
# 772         55.57    0.47      0.2   0.094    0.37      0.2   0.074   1.355
# 773         55.57    0.24      0.2   0.180    0.42      0.2   0.008   0.280
# 774         55.57    0.20      0.2   0.040    0.00      0.2   0.000   0.200
# 775         55.57    0.00      0.2   0.000    0.00      0.2   0.000   0.000
#
#      numbers  Score_B.1  ...  RiSk_E  History  Prob  Risk_F  Score  \
# 0        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.4
# 1        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 2        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 3        6.0        0.6  ...     0.4      0.0   0.2     0.0    4.4
# 4        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.4
# ..       ...        ...  ...     ...      ...   ...     ...    ...
# 771      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 772      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 773      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 774      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 775      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
#
#      Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0            8.574           0.4             0.5      1.7148   1.0
# 1            2.554           0.4             0.5      0.5108   0.0
# 2            1.548           0.4             0.5      0.3096   0.0
# 3           17.530           0.4             0.5      3.5060   1.0
# 4            1.416           0.4             0.5      0.2832   0.0
# ..             ...           ...             ...         ...   ...
# 771          1.578           0.4             0.5      0.3156   0.0
# 772          1.568           0.4             0.5      0.5900   0.0
# 773          1.456           0.4             0.5      0.2912   0.0
# 774          2.214           0.4             0.5      0.2880   0.0
# 775          1.464           0.4             0.5      0.2928   0.0
#
# [776 rows x 26 columns]

# %%
df2.describe()
# Out:
#        Sector_score      PARA_A     Score_A      Risk_A      PARA_B  \
# count    776.000000  776.000000  776.000000  776.000000  776.000000
# mean      19.070593    2.346122    0.336856    1.280655    8.566352
# std       23.833817    5.618820    0.171769    3.424103   21.577577
# min        1.850000    0.000000    0.200000    0.000000    0.000000
# 25%        2.370000    0.270000    0.200000    0.062000    0.000000
# 50%        3.890000    0.890000    0.200000    0.180000    0.420000
# 75%       55.570000    2.212500    0.600000    1.311000    2.372500
# max       59.850000   85.000000    0.600000   51.000000  144.390000
#
#           Score_B      Risk_B        TOTAL     numbers   Score_B.1  ...  \
# count  776.000000  776.000000   776.000000  776.000000  776.000000  ...
# mean     0.301804    5.942835    11.519407    5.058634    0.220619  ...
# std      0.165071   29.988657    50.526976    0.250373    0.076623  ...
# min      0.200000    0.000000     0.000000    5.000000    0.200000  ...
# 25%      0.200000    0.000000     0.680000    5.000000    0.200000  ...
# 50%      0.200000    0.078000     1.355000    5.000000    0.200000  ...
# 75%      0.400000    0.663000     5.622500    5.000000    0.200000  ...
# max      0.600000  758.778000  1268.910000    9.000000    0.600000  ...
#
#            RiSk_E     History        Prob      Risk_F       Score  \
# count  776.000000  776.000000  776.000000  776.000000  776.000000
# mean     0.503608    0.096649    0.215206    0.045361    2.683247
# std      0.272219    0.522712    0.064464    0.287016    0.826233
# min      0.400000    0.000000    0.200000    0.000000    2.000000
# 25%      0.400000    0.000000    0.200000    0.000000    2.000000
# 50%      0.400000    0.000000    0.200000    0.000000    2.400000
# 75%      0.400000    0.000000    0.200000    0.000000    3.200000
# max      2.400000    9.000000    0.600000    5.400000    5.200000
#
#        Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk        Risk
# count     776.000000    776.000000           776.0  776.000000  776.000000
# mean       14.110833      0.547423             0.5    6.047399    0.393041
# std        37.775594      0.417821             0.0   37.001800    0.488741
# min         1.400000      0.400000             0.5    0.280000    0.000000
# 25%         1.616500      0.400000             0.5    0.327300    0.000000
# 50%         2.214000      0.400000             0.5    0.590000    0.000000
# 75%         8.055000      0.400000             0.5    2.438400    1.000000
# max       583.688000      5.800000             0.5  961.514400    1.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
x = df2.iloc[:, :-1].values
y = df2.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=26)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = MLPClassifier(hidden_layer_sizes=3, learning_rate_init=0.1, max_iter=100)
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[105   1]
#  [  8  80]]
# 0.9536082474226805
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
