# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("parkinson_10%.csv")

# %%
df
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0           NaN           0.79
# 1               0.73                       0.0          0.35           0.38
# 2               1.22                       0.0          0.73           0.67
# 3               2.50                       0.0          1.16            NaN
# 4                NaN                       0.0          1.72            NaN
# ...              ...                       ...           ...            ...
# 1035            5.13                       0.0          2.72           2.51
# 1036            1.76                       0.0           NaN           0.69
# 1037            2.91                       0.0          1.14           1.27
# 1038            3.79                       0.0          1.79           1.48
# 1039             NaN                       0.0          0.68           0.84
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 0             2.70             8.33                 0.78            4.52
# 1              NaN             5.86                 0.64            2.06
# 2              NaN             8.72                 0.88            4.35
# 3             3.47            13.51                  NaN            5.26
# 4             5.15             9.11                 1.04            3.10
# ...            ...              ...                  ...             ...
# 1035          8.16             9.85                 0.97            4.59
# 1036          2.43              NaN                 0.74            2.72
# 1037          3.42            15.49                 1.46            6.43
# 1038          5.36            15.70                 1.37            6.37
# 1039          2.04             7.88                 0.78            2.69
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 0               4.61             6.80  ...         187.58             160.0
# 1               3.18             7.19  ...         234.51             170.0
# 2               5.17              NaN  ...         211.44            1431.0
# 3               8.77            16.78  ...         220.23              94.0
# 4               4.93            12.82  ...            NaN             117.0
# ...              ...              ...  ...            ...               ...
# 1035            6.81             8.30  ...         158.59              63.0
# 1036            3.93              NaN  ...         143.80              47.0
# 1037           10.14            14.24  ...         149.64              79.0
# 1038           11.09              NaN  ...         451.37              75.0
# 1039             NaN            11.07  ...         137.55              62.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 0                   NaN         0.01                           0.0
# 1                 169.0         0.01                           0.0
# 2                   NaN         0.01                           0.0
# 3                  92.0         0.00                           0.0
# 4                 114.0         0.00                           0.0
# ...                 ...          ...                           ...
# 1035               60.0         0.01                           0.0
# 1036               44.0         0.01                           0.0
# 1037               77.0         0.01                           0.0
# 1038               70.0         0.01                           0.0
# 1039               60.0          NaN                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                    0.00                     0.0
# 1                                    2.25                     0.0
# 2                                   10.66                     1.0
# 3                                    0.00                     0.0
# 4                                   18.18                     NaN
# ...                                   ...                     ...
# 1035                                24.19                     2.0
# 1036                                  NaN                     NaN
# 1037                                20.00                     1.0
# 1038                                16.67                     3.0
# 1039                                18.18                     1.0
#
#       Degree of voice breaks  UPDRS  class
# 0                       0.00   23.0      1
# 1                       0.00   23.0      1
# 2                       0.18   23.0      1
# 3                       0.00   23.0      1
# 4                      13.32   23.0      1
# ...                      ...    ...    ...
# 1035                   15.11    1.0      0
# 1036                   25.79    1.0      0
# 1037                    4.57    1.0      0
# 1038                   19.58    1.0      0
# 1039                    3.39    1.0      0
#
# [1040 rows x 28 columns]

# %%
df.dtypes
# Out:
# Jitter (local)                         float64
# Jitter (local, absolute)               float64
# Jitter (rap)                           float64
# Jitter (ppq5)                          float64
# Jitter (ddp)                           float64
# Shimmer (local)                        float64
# Shimmer (local, dB)                    float64
# Shimmer (apq3)                         float64
# Shimmer (apq5)                         float64
# Shimmer (apq11)                        float64
# Shimmer (dda)                          float64
# AC                                     float64
# NTH                                    float64
# HTN                                    float64
# Median pitch                           float64
# Mean pitch                             float64
# Standard deviation                     float64
# Minimum pitch                          float64
# Maximum pitch                          float64
# Number of pulses                       float64
# Number of periods                      float64
# Mean period                            float64
# Standard deviation of period           float64
# Fraction of locally unvoiced frames    float64
# Number of voice breaks                 float64
# Degree of voice breaks                 float64
# UPDRS                                  float64
# class                                    int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Jitter (local)                         110
# Jitter (local, absolute)               119
# Jitter (rap)                           110
# Jitter (ppq5)                          112
# Jitter (ddp)                           112
# Shimmer (local)                        106
# Shimmer (local, dB)                    101
# Shimmer (apq3)                         100
# Shimmer (apq5)                          99
# Shimmer (apq11)                         94
# Shimmer (dda)                          106
# AC                                     110
# NTH                                    110
# HTN                                    111
# Median pitch                           119
# Mean pitch                             112
# Standard deviation                     103
# Minimum pitch                          125
# Maximum pitch                          119
# Number of pulses                       102
# Number of periods                      111
# Mean period                            113
# Standard deviation of period           100
# Fraction of locally unvoiced frames    110
# Number of voice breaks                 100
# Degree of voice breaks                 100
# UPDRS                                   98
# class                                    0
# dtype: int64

# %%
null_counts = df.isnull().sum()
null_percentages = 100 * null_counts / len(df)
null_percentages
# Out:
# Jitter (local)                         10.576923
# Jitter (local, absolute)               11.442308
# Jitter (rap)                           10.576923
# Jitter (ppq5)                          10.769231
# Jitter (ddp)                           10.769231
# Shimmer (local)                        10.192308
# Shimmer (local, dB)                     9.711538
# Shimmer (apq3)                          9.615385
# Shimmer (apq5)                          9.519231
# Shimmer (apq11)                         9.038462
# Shimmer (dda)                          10.192308
# AC                                     10.576923
# NTH                                    10.576923
# HTN                                    10.673077
# Median pitch                           11.442308
# Mean pitch                             10.769231
# Standard deviation                      9.903846
# Minimum pitch                          12.019231
# Maximum pitch                          11.442308
# Number of pulses                        9.807692
# Number of periods                      10.673077
# Mean period                            10.865385
# Standard deviation of period            9.615385
# Fraction of locally unvoiced frames    10.576923
# Number of voice breaks                  9.615385
# Degree of voice breaks                  9.615385
# UPDRS                                   9.423077
# class                                   0.000000
# dtype: float64

# %%
null_counts = df.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase hilang :",null_percentages)
# Out:
# total nilai : 29120
# nilai hilang : 2912
# persentase hilang : 10.0

# %% [markdown]
# # Imputasi Median

# %%
df2 = df.fillna(df.median())

# %%
df2
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0          1.03           0.79
# 1               0.73                       0.0          0.35           0.38
# 2               1.22                       0.0          0.73           0.67
# 3               2.50                       0.0          1.16           1.13
# 4               2.41                       0.0          1.72           1.13
# ...              ...                       ...           ...            ...
# 1035            5.13                       0.0          2.72           2.51
# 1036            1.76                       0.0          1.03           0.69
# 1037            2.91                       0.0          1.14           1.27
# 1038            3.79                       0.0          1.79           1.48
# 1039            2.41                       0.0          0.68           0.84
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 0            2.700            8.330                 0.78            4.52
# 1            3.105            5.860                 0.64            2.06
# 2            3.105            8.720                 0.88            4.35
# 3            3.470           13.510                 1.18            5.26
# 4            5.150            9.110                 1.04            3.10
# ...            ...              ...                  ...             ...
# 1035         8.160            9.850                 0.97            4.59
# 1036         2.430           12.285                 0.74            2.72
# 1037         3.420           15.490                 1.46            6.43
# 1038         5.360           15.700                 1.37            6.37
# 1039         2.040            7.880                 0.78            2.69
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 0               4.61             6.80  ...         187.58             160.0
# 1               3.18             7.19  ...         234.51             170.0
# 2               5.17            11.42  ...         211.44            1431.0
# 3               8.77            16.78  ...         220.23              94.0
# 4               4.93            12.82  ...         196.62             117.0
# ...              ...              ...  ...            ...               ...
# 1035            6.81             8.30  ...         158.59              63.0
# 1036            3.93            11.42  ...         143.80              47.0
# 1037           10.14            14.24  ...         149.64              79.0
# 1038           11.09            11.42  ...         451.37              75.0
# 1039            7.04            11.07  ...         137.55              62.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 0                  62.0         0.01                           0.0
# 1                 169.0         0.01                           0.0
# 2                  62.0         0.01                           0.0
# 3                  92.0         0.00                           0.0
# 4                 114.0         0.00                           0.0
# ...                 ...          ...                           ...
# 1035               60.0         0.01                           0.0
# 1036               44.0         0.01                           0.0
# 1037               77.0         0.01                           0.0
# 1038               70.0         0.01                           0.0
# 1039               60.0         0.01                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                   0.000                     0.0
# 1                                   2.250                     0.0
# 2                                  10.660                     1.0
# 3                                   0.000                     0.0
# 4                                  18.180                     1.0
# ...                                   ...                     ...
# 1035                               24.190                     2.0
# 1036                               26.615                     1.0
# 1037                               20.000                     1.0
# 1038                               16.670                     3.0
# 1039                               18.180                     1.0
#
#       Degree of voice breaks  UPDRS  class
# 0                       0.00   23.0      1
# 1                       0.00   23.0      1
# 2                       0.18   23.0      1
# 3                       0.00   23.0      1
# 4                      13.32   23.0      1
# ...                      ...    ...    ...
# 1035                   15.11    1.0      0
# 1036                   25.79    1.0      0
# 1037                    4.57    1.0      0
# 1038                   19.58    1.0      0
# 1039                    3.39    1.0      0
#
# [1040 rows x 28 columns]

# %%
df2.describe()
# Out:
#        Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# count     1040.000000                    1040.0   1040.000000    1040.000000
# mean         2.666269                       0.0      1.210308       1.337606
# std          1.683492                       0.0      0.886902       1.094251
# min          0.190000                       0.0      0.060000       0.080000
# 25%          1.650000                       0.0      0.660000       0.720000
# 50%          2.410000                       0.0      1.030000       1.130000
# 75%          3.302500                       0.0      1.512500       1.620000
# max         14.380000                       0.0      8.020000      13.540000
#
#        Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# count   1040.000000      1040.000000          1040.000000     1040.000000
# mean       3.678163        12.870433             1.188308        5.624058
# std        2.771461         5.217636             0.398272        2.831108
# min        0.190000         1.190000             0.100000        0.500000
# 25%        2.040000         9.772500             0.970000        3.850000
# 50%        3.105000        12.285000             1.180000        5.145000
# 75%        4.545000        14.852500             1.370000        6.680000
# max       24.050000        41.140000             2.720000       25.820000
#
#        Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# count     1040.000000      1040.000000  ...    1040.000000       1040.000000
# mean         7.900702        12.123587  ...     231.335442        106.876923
# std          4.670846         5.761662  ...     115.238755        148.413063
# min          0.710000         0.520000  ...      85.540000          0.000000
# 25%          5.387500         8.637500  ...     149.592500         44.000000
# 50%          7.040000        11.420000  ...     196.620000         64.000000
# 75%          9.140000        14.732500  ...     253.617500        106.000000
# max         72.860000        44.760000  ...     526.410000       1490.000000
#
#        Number of periods  Mean period  Standard deviation of period  \
# count        1040.000000  1040.000000                    1040.00000
# mean          100.423077     0.007798                       0.00001
# std           133.864913     0.004146                       0.00031
# min             0.000000     0.000000                       0.00000
# 25%            43.000000     0.010000                       0.00000
# 50%            62.000000     0.010000                       0.00000
# 75%           101.000000     0.010000                       0.00000
# max          1483.000000     0.010000                       0.01000
#
#        Fraction of locally unvoiced frames  Number of voice breaks  \
# count                          1040.000000             1040.000000
# mean                             27.626740                1.137500
# std                              19.942028                1.544133
# min                               0.000000                0.000000
# 25%                              10.245000                0.000000
# 50%                              26.615000                1.000000
# 75%                              41.320000                1.000000
# max                              88.160000               12.000000
#
#        Degree of voice breaks        UPDRS        class
# count             1040.000000  1040.000000  1040.000000
# mean                11.499288    12.076923     0.500000
# std                 14.315705    15.425871     0.500241
# min                  0.000000     1.000000     0.000000
# 25%                  0.000000     1.000000     0.000000
# 50%                  5.405000     3.000000     0.500000
# 75%                 19.705000    23.000000     1.000000
# max                 69.120000    55.000000     1.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
x = df2.iloc[:, :-1].values
y = df2.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=11)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[122  16]
#  [ 29  93]]
# 0.8269230769230769
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[124  14]
#  [ 28  94]]
# 0.8384615384615385
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=7, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[127  11]
#  [ 29  93]]
# 0.8461538461538461
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=9, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[129   9]
#  [ 30  92]]
# 0.85
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
