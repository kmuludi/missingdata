# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("parkinson_10%.csv")

# %%
df
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0           NaN           0.79
# 1               0.73                       0.0          0.35           0.38
# 2               1.22                       0.0          0.73           0.67
# 3               2.50                       0.0          1.16            NaN
# 4                NaN                       0.0          1.72            NaN
# ...              ...                       ...           ...            ...
# 1035            5.13                       0.0          2.72           2.51
# 1036            1.76                       0.0           NaN           0.69
# 1037            2.91                       0.0          1.14           1.27
# 1038            3.79                       0.0          1.79           1.48
# 1039             NaN                       0.0          0.68           0.84
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 0             2.70             8.33                 0.78            4.52
# 1              NaN             5.86                 0.64            2.06
# 2              NaN             8.72                 0.88            4.35
# 3             3.47            13.51                  NaN            5.26
# 4             5.15             9.11                 1.04            3.10
# ...            ...              ...                  ...             ...
# 1035          8.16             9.85                 0.97            4.59
# 1036          2.43              NaN                 0.74            2.72
# 1037          3.42            15.49                 1.46            6.43
# 1038          5.36            15.70                 1.37            6.37
# 1039          2.04             7.88                 0.78            2.69
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 0               4.61             6.80  ...         187.58             160.0
# 1               3.18             7.19  ...         234.51             170.0
# 2               5.17              NaN  ...         211.44            1431.0
# 3               8.77            16.78  ...         220.23              94.0
# 4               4.93            12.82  ...            NaN             117.0
# ...              ...              ...  ...            ...               ...
# 1035            6.81             8.30  ...         158.59              63.0
# 1036            3.93              NaN  ...         143.80              47.0
# 1037           10.14            14.24  ...         149.64              79.0
# 1038           11.09              NaN  ...         451.37              75.0
# 1039             NaN            11.07  ...         137.55              62.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 0                   NaN         0.01                           0.0
# 1                 169.0         0.01                           0.0
# 2                   NaN         0.01                           0.0
# 3                  92.0         0.00                           0.0
# 4                 114.0         0.00                           0.0
# ...                 ...          ...                           ...
# 1035               60.0         0.01                           0.0
# 1036               44.0         0.01                           0.0
# 1037               77.0         0.01                           0.0
# 1038               70.0         0.01                           0.0
# 1039               60.0          NaN                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                    0.00                     0.0
# 1                                    2.25                     0.0
# 2                                   10.66                     1.0
# 3                                    0.00                     0.0
# 4                                   18.18                     NaN
# ...                                   ...                     ...
# 1035                                24.19                     2.0
# 1036                                  NaN                     NaN
# 1037                                20.00                     1.0
# 1038                                16.67                     3.0
# 1039                                18.18                     1.0
#
#       Degree of voice breaks  UPDRS  class
# 0                       0.00   23.0      1
# 1                       0.00   23.0      1
# 2                       0.18   23.0      1
# 3                       0.00   23.0      1
# 4                      13.32   23.0      1
# ...                      ...    ...    ...
# 1035                   15.11    1.0      0
# 1036                   25.79    1.0      0
# 1037                    4.57    1.0      0
# 1038                   19.58    1.0      0
# 1039                    3.39    1.0      0
#
# [1040 rows x 28 columns]

# %%
df.dtypes
# Out:
# Jitter (local)                         float64
# Jitter (local, absolute)               float64
# Jitter (rap)                           float64
# Jitter (ppq5)                          float64
# Jitter (ddp)                           float64
# Shimmer (local)                        float64
# Shimmer (local, dB)                    float64
# Shimmer (apq3)                         float64
# Shimmer (apq5)                         float64
# Shimmer (apq11)                        float64
# Shimmer (dda)                          float64
# AC                                     float64
# NTH                                    float64
# HTN                                    float64
# Median pitch                           float64
# Mean pitch                             float64
# Standard deviation                     float64
# Minimum pitch                          float64
# Maximum pitch                          float64
# Number of pulses                       float64
# Number of periods                      float64
# Mean period                            float64
# Standard deviation of period           float64
# Fraction of locally unvoiced frames    float64
# Number of voice breaks                 float64
# Degree of voice breaks                 float64
# UPDRS                                  float64
# class                                    int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Jitter (local)                         110
# Jitter (local, absolute)               119
# Jitter (rap)                           110
# Jitter (ppq5)                          112
# Jitter (ddp)                           112
# Shimmer (local)                        106
# Shimmer (local, dB)                    101
# Shimmer (apq3)                         100
# Shimmer (apq5)                          99
# Shimmer (apq11)                         94
# Shimmer (dda)                          106
# AC                                     110
# NTH                                    110
# HTN                                    111
# Median pitch                           119
# Mean pitch                             112
# Standard deviation                     103
# Minimum pitch                          125
# Maximum pitch                          119
# Number of pulses                       102
# Number of periods                      111
# Mean period                            113
# Standard deviation of period           100
# Fraction of locally unvoiced frames    110
# Number of voice breaks                 100
# Degree of voice breaks                 100
# UPDRS                                   98
# class                                    0
# dtype: int64

# %%
null_counts = df.isnull().sum()
null_percentages = 100 * null_counts / len(df)
null_percentages
# Out:
# Jitter (local)                         10.576923
# Jitter (local, absolute)               11.442308
# Jitter (rap)                           10.576923
# Jitter (ppq5)                          10.769231
# Jitter (ddp)                           10.769231
# Shimmer (local)                        10.192308
# Shimmer (local, dB)                     9.711538
# Shimmer (apq3)                          9.615385
# Shimmer (apq5)                          9.519231
# Shimmer (apq11)                         9.038462
# Shimmer (dda)                          10.192308
# AC                                     10.576923
# NTH                                    10.576923
# HTN                                    10.673077
# Median pitch                           11.442308
# Mean pitch                             10.769231
# Standard deviation                      9.903846
# Minimum pitch                          12.019231
# Maximum pitch                          11.442308
# Number of pulses                        9.807692
# Number of periods                      10.673077
# Mean period                            10.865385
# Standard deviation of period            9.615385
# Fraction of locally unvoiced frames    10.576923
# Number of voice breaks                  9.615385
# Degree of voice breaks                  9.615385
# UPDRS                                   9.423077
# class                                   0.000000
# dtype: float64

# %%
null_counts = df.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase hilang :",null_percentages)
# Out:
# total nilai : 29120
# nilai hilang : 2912
# persentase hilang : 10.0

# %% [markdown]
# # Hapus Nilai Hilang

# %%
df2 = df.dropna(axis=0)
df2
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 12              2.11                       0.0          0.90           1.08
# 22              4.00                       0.0          1.93           2.23
# 24              1.73                       0.0          0.81           0.82
# 40              2.03                       0.0          1.01           1.09
# 50              2.72                       0.0          1.25           1.59
# ...              ...                       ...           ...            ...
# 998             1.31                       0.0          0.64           0.45
# 1005            3.31                       0.0          1.42           1.11
# 1030            4.34                       0.0          1.92           2.29
# 1031            7.04                       0.0          3.07           2.80
# 1035            5.13                       0.0          2.72           2.51
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 12            2.71             6.16                 0.72            2.40
# 22            5.78            16.51                 1.36            7.85
# 24            2.43            12.26                 1.07            4.77
# 40            3.02             9.97                 1.10            3.75
# 50            3.76             9.80                 0.97            3.70
# ...            ...              ...                  ...             ...
# 998           1.91            13.98                 1.36            7.24
# 1005          4.27             8.45                 0.71            4.13
# 1030          5.77            13.00                 1.33            5.47
# 1031          9.21            19.95                 1.67           10.60
# 1035          8.16             9.85                 0.97            4.59
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 12              3.16             5.01  ...         217.45             107.0
# 22             11.73            16.95  ...         245.63              81.0
# 24              8.44            15.48  ...         260.81             101.0
# 40              5.72            12.92  ...         131.34             141.0
# 50              5.83            11.57  ...         141.64              64.0
# ...              ...              ...  ...            ...               ...
# 998             7.92            11.35  ...         178.45              24.0
# 1005            5.73             4.97  ...         182.17              27.0
# 1030            8.70            14.45  ...         207.65             246.0
# 1031           14.70            22.38  ...         178.37              45.0
# 1035            6.81             8.30  ...         158.59              63.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 12                104.0         0.01                           0.0
# 22                 79.0         0.00                           0.0
# 24                 99.0         0.00                           0.0
# 40                140.0         0.01                           0.0
# 50                 62.0         0.01                           0.0
# ...                 ...          ...                           ...
# 998                23.0         0.01                           0.0
# 1005               25.0         0.01                           0.0
# 1030              238.0         0.01                           0.0
# 1031               42.0         0.01                           0.0
# 1035               60.0         0.01                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 12                                   0.00                     0.0
# 22                                  36.07                     1.0
# 24                                   7.41                     1.0
# 40                                   1.72                     0.0
# 50                                  10.00                     1.0
# ...                                   ...                     ...
# 998                                 73.59                     0.0
# 1005                                48.49                     0.0
# 1030                                34.43                     5.0
# 1031                                13.51                     1.0
# 1035                                24.19                     2.0
#
#       Degree of voice breaks  UPDRS  class
# 12                      0.00   23.0      1
# 22                     18.92   23.0      1
# 24                      3.65   23.0      1
# 40                      0.00    8.0      1
# 50                      7.91    8.0      1
# ...                      ...    ...    ...
# 998                     0.00    1.0      0
# 1005                    0.00    1.0      0
# 1030                   34.51    1.0      0
# 1031                    8.92    1.0      0
# 1035                   15.11    1.0      0
#
# [61 rows x 28 columns]

# %%
df2.describe()
# Out:
#        Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# count       61.000000                      61.0     61.000000      61.000000
# mean         2.751311                       0.0      1.268033       1.323607
# std          1.429386                       0.0      0.769450       0.797624
# min          0.290000                       0.0      0.130000       0.150000
# 25%          1.740000                       0.0      0.730000       0.710000
# 50%          2.440000                       0.0      1.040000       1.130000
# 75%          3.620000                       0.0      1.790000       1.840000
# max          7.040000                       0.0      3.540000       3.930000
#
#        Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# count     61.000000        61.000000            61.000000       61.000000
# mean       3.803443        12.140984             1.160492        5.521475
# std        2.308348         4.444617             0.359149        2.389366
# min        0.400000         2.340000             0.260000        1.200000
# 25%        2.200000         9.490000             0.960000        3.880000
# 50%        3.130000        11.460000             1.100000        5.060000
# 75%        5.360000        14.410000             1.340000        6.350000
# max       10.630000        26.700000             2.450000       14.150000
#
#        Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# count       61.000000        61.000000  ...      61.000000         61.000000
# mean         7.660492        12.150328  ...     249.238525        122.196721
# std          3.453449         6.264975  ...     120.935717        153.955385
# min          1.390000         1.670000  ...     117.550000         12.000000
# 25%          5.290000         7.580000  ...     160.960000         41.000000
# 50%          6.560000        11.350000  ...     207.650000         74.000000
# 75%          9.850000        14.720000  ...     309.440000        123.000000
# max         18.510000        39.850000  ...     504.990000        854.000000
#
#        Number of periods  Mean period  Standard deviation of period  \
# count          61.000000    61.000000                          61.0
# mean          118.081967     0.007705                           0.0
# std           152.555705     0.004240                           0.0
# min            11.000000     0.000000                           0.0
# 25%            40.000000     0.010000                           0.0
# 50%            63.000000     0.010000                           0.0
# 75%           121.000000     0.010000                           0.0
# max           843.000000     0.010000                           0.0
#
#        Fraction of locally unvoiced frames  Number of voice breaks  \
# count                            61.000000               61.000000
# mean                             28.738361                1.311475
# std                              19.881871                1.708225
# min                               0.000000                0.000000
# 25%                              13.510000                0.000000
# 50%                              28.670000                1.000000
# 75%                              41.880000                2.000000
# max                              77.190000                8.000000
#
#        Degree of voice breaks      UPDRS      class
# count               61.000000  61.000000  61.000000
# mean                13.026721  11.754098   0.459016
# std                 13.452734  16.533457   0.502453
# min                  0.000000   1.000000   0.000000
# 25%                  0.000000   1.000000   0.000000
# 50%                  9.440000   1.000000   0.000000
# 75%                 22.620000  23.000000   1.000000
# max                 46.670000  55.000000   1.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
x = df2.iloc[:, :-1].values
y = df2.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Definisikan range parameter untuk grid search
param_grid = {
    'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50), (100, 100)],
    'learning_rate_init': [0.001, 0.01, 0.1]
}

# %%
classifier = MLPClassifier()
grid_search = GridSearchCV(classifier, param_grid, cv=5, n_jobs=-1)
grid_search.fit(x, y)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Accuracy:", best_score)
# Out:
# Best Parameters: {'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.01}
# Best Accuracy: 0.8179487179487179
