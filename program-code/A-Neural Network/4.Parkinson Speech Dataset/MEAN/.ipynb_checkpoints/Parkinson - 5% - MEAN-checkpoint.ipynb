# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("parkinson_5%.csv")

# %%
df
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0          0.90            NaN
# 1               0.73                       0.0          0.35           0.38
# 2               1.22                       0.0          0.73           0.67
# 3               2.50                       0.0          1.16           1.63
# 4               3.51                       0.0          1.72           1.54
# ...              ...                       ...           ...            ...
# 1035            5.13                       0.0          2.72           2.51
# 1036            1.76                       NaN           NaN           0.69
# 1037            2.91                       0.0          1.14           1.27
# 1038            3.79                       0.0          1.79           1.48
# 1039            1.81                       0.0          0.68           0.84
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 0             2.70             8.33                 0.78            4.52
# 1             1.06             5.86                 0.64             NaN
# 2             2.20             8.72                 0.88            4.35
# 3             3.47            13.51                  NaN            5.26
# 4             5.15             9.11                 1.04            3.10
# ...            ...              ...                  ...             ...
# 1035          8.16             9.85                 0.97            4.59
# 1036          2.43             7.57                 0.74            2.72
# 1037          3.42            15.49                 1.46            6.43
# 1038          5.36            15.70                 1.37            6.37
# 1039          2.04             7.88                 0.78             NaN
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 0               4.61             6.80  ...         187.58             160.0
# 1               3.18             7.19  ...         234.51             170.0
# 2               5.17             7.55  ...         211.44            1431.0
# 3               8.77            16.78  ...         220.23              94.0
# 4               4.93            12.82  ...         225.16             117.0
# ...              ...              ...  ...            ...               ...
# 1035            6.81             8.30  ...         158.59              63.0
# 1036             NaN            11.93  ...         143.80              47.0
# 1037             NaN            14.24  ...         149.64              79.0
# 1038           11.09            18.82  ...         451.37              75.0
# 1039            4.54              NaN  ...            NaN              62.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 0                 159.0         0.01                           0.0
# 1                 169.0         0.01                           NaN
# 2                1427.0         0.01                           0.0
# 3                  92.0         0.00                           0.0
# 4                 114.0         0.00                           0.0
# ...                 ...          ...                           ...
# 1035               60.0         0.01                           0.0
# 1036               44.0         0.01                           0.0
# 1037               77.0         0.01                           NaN
# 1038               70.0         0.01                           0.0
# 1039               60.0         0.01                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                    0.00                     0.0
# 1                                    2.25                     0.0
# 2                                   10.66                     1.0
# 3                                     NaN                     0.0
# 4                                   18.18                     1.0
# ...                                   ...                     ...
# 1035                                24.19                     2.0
# 1036                                46.05                     1.0
# 1037                                20.00                     1.0
# 1038                                  NaN                     3.0
# 1039                                18.18                     1.0
#
#       Degree of voice breaks  features 27  class
# 0                       0.00         23.0    1.0
# 1                       0.00         23.0    1.0
# 2                       0.18         23.0    1.0
# 3                       0.00         23.0    1.0
# 4                      13.32         23.0    1.0
# ...                      ...          ...    ...
# 1035                   15.11          1.0    0.0
# 1036                   25.79          1.0    0.0
# 1037                    4.57          1.0    0.0
# 1038                   19.58          1.0    0.0
# 1039                    3.39          1.0    0.0
#
# [1040 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# Jitter (local)                         56
# Jitter (local, absolute)               55
# Jitter (rap)                           60
# Jitter (ppq5)                          52
# Jitter (ddp)                           59
# Shimmer (local)                        37
# Shimmer (local, dB)                    54
# Shimmer (apq3)                         44
# Shimmer (apq5)                         71
# Shimmer (apq11)                        60
# Shimmer (dda)                          51
# AC                                     50
# NTH                                    51
# HTN                                    59
# Median pitch                           54
# Mean pitch                             69
# Standard deviation                     52
# Minimum pitch                          53
# Maximum pitch                          52
# Number of pulses                       57
# Number of periods                      46
# Mean period                            56
# Standard deviation of period           53
# Fraction of locally unvoiced frames    60
# Number of voice breaks                 46
# Degree of voice breaks                 50
# features 27                            49
# class                                   0
# dtype: int64

# %%
null_counts = df.isnull().sum()
null_percentages = 100 * null_counts / len(df)
null_percentages
# Out:
# Jitter (local)                         5.384615
# Jitter (local, absolute)               5.288462
# Jitter (rap)                           5.769231
# Jitter (ppq5)                          5.000000
# Jitter (ddp)                           5.673077
# Shimmer (local)                        3.557692
# Shimmer (local, dB)                    5.192308
# Shimmer (apq3)                         4.230769
# Shimmer (apq5)                         6.826923
# Shimmer (apq11)                        5.769231
# Shimmer (dda)                          4.903846
# AC                                     4.807692
# NTH                                    4.903846
# HTN                                    5.673077
# Median pitch                           5.192308
# Mean pitch                             6.634615
# Standard deviation                     5.000000
# Minimum pitch                          5.096154
# Maximum pitch                          5.000000
# Number of pulses                       5.480769
# Number of periods                      4.423077
# Mean period                            5.384615
# Standard deviation of period           5.096154
# Fraction of locally unvoiced frames    5.769231
# Number of voice breaks                 4.423077
# Degree of voice breaks                 4.807692
# features 27                            4.711538
# class                                  0.000000
# dtype: float64

# %%
null_counts = df.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase hilang :",null_percentages)
# Out:
# total nilai : 29120
# nilai hilang : 1456
# persentase hilang : 5.0

# %% [markdown]
# # Imputasi Mean

# %%
df2 = df.fillna(df.mean())

# %%
df2
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0      0.900000       1.352601
# 1               0.73                       0.0      0.350000       0.380000
# 2               1.22                       0.0      0.730000       0.670000
# 3               2.50                       0.0      1.160000       1.630000
# 4               3.51                       0.0      1.720000       1.540000
# ...              ...                       ...           ...            ...
# 1035            5.13                       0.0      2.720000       2.510000
# 1036            1.76                       0.0      1.250765       0.690000
# 1037            2.91                       0.0      1.140000       1.270000
# 1038            3.79                       0.0      1.790000       1.480000
# 1039            1.81                       0.0      0.680000       0.840000
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 0             2.70             8.33             0.780000        4.520000
# 1             1.06             5.86             0.640000        5.702691
# 2             2.20             8.72             0.880000        4.350000
# 3             3.47            13.51             1.192414        5.260000
# 4             5.15             9.11             1.040000        3.100000
# ...            ...              ...                  ...             ...
# 1035          8.16             9.85             0.970000        4.590000
# 1036          2.43             7.57             0.740000        2.720000
# 1037          3.42            15.49             1.460000        6.430000
# 1038          5.36            15.70             1.370000        6.370000
# 1039          2.04             7.88             0.780000        5.702691
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 0           4.610000         6.800000  ...     187.580000             160.0
# 1           3.180000         7.190000  ...     234.510000             170.0
# 2           5.170000         7.550000  ...     211.440000            1431.0
# 3           8.770000        16.780000  ...     220.230000              94.0
# 4           4.930000        12.820000  ...     225.160000             117.0
# ...              ...              ...  ...            ...               ...
# 1035        6.810000         8.300000  ...     158.590000              63.0
# 1036        7.965005        11.930000  ...     143.800000              47.0
# 1037        7.965005        14.240000  ...     149.640000              79.0
# 1038       11.090000        18.820000  ...     451.370000              75.0
# 1039        4.540000        12.165235  ...     235.821164              62.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 0                 159.0         0.01                       0.00000
# 1                 169.0         0.01                       0.00001
# 2                1427.0         0.01                       0.00000
# 3                  92.0         0.00                       0.00000
# 4                 114.0         0.00                       0.00000
# ...                 ...          ...                           ...
# 1035               60.0         0.01                       0.00000
# 1036               44.0         0.01                       0.00000
# 1037               77.0         0.01                       0.00001
# 1038               70.0         0.01                       0.00000
# 1039               60.0         0.01                       0.00000
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                0.000000                     0.0
# 1                                2.250000                     0.0
# 2                               10.660000                     1.0
# 3                               27.756796                     0.0
# 4                               18.180000                     1.0
# ...                                   ...                     ...
# 1035                            24.190000                     2.0
# 1036                            46.050000                     1.0
# 1037                            20.000000                     1.0
# 1038                            27.756796                     3.0
# 1039                            18.180000                     1.0
#
#       Degree of voice breaks  features 27  class
# 0                       0.00         23.0    1.0
# 1                       0.00         23.0    1.0
# 2                       0.18         23.0    1.0
# 3                       0.00         23.0    1.0
# 4                      13.32         23.0    1.0
# ...                      ...          ...    ...
# 1035                   15.11          1.0    0.0
# 1036                   25.79          1.0    0.0
# 1037                    4.57          1.0    0.0
# 1038                   19.58          1.0    0.0
# 1039                    3.39          1.0    0.0
#
# [1040 rows x 28 columns]

# %%
df2.describe()
# Out:
#        Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# count     1040.000000                    1040.0   1040.000000    1040.000000
# mean         2.682358                       0.0      1.250765       1.352601
# std          1.728341                       0.0      0.963589       1.123153
# min          0.190000                       0.0      0.060000       0.080000
# 25%          1.550000                       0.0      0.640000       0.690000
# 50%          2.480000                       0.0      1.100000       1.165000
# 75%          3.340000                       0.0      1.572500       1.650000
# max         14.380000                       0.0      8.020000      13.540000
#
#        Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# count   1040.000000      1040.000000          1040.000000     1040.000000
# mean       3.765933        12.917797             1.192414        5.702691
# std        2.873612         5.350357             0.407348        2.962126
# min        0.190000         1.190000             0.100000        0.500000
# 25%        1.950000         9.505000             0.960000        3.767500
# 50%        3.300000        12.540000             1.192414        5.260000
# 75%        4.752500        15.355000             1.390000        6.807500
# max       24.050000        41.140000             2.720000       25.820000
#
#        Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# count     1040.000000      1040.000000  ...    1040.000000       1040.000000
# mean         7.965005        12.165235  ...     235.821164        109.630722
# std          4.702441         5.739730  ...     119.283658        147.925608
# min          0.710000         0.520000  ...      85.540000          0.000000
# 25%          5.310000         8.517500  ...     145.690000         43.000000
# 50%          7.385000        11.705000  ...     202.240000         67.000000
# 75%          9.197500        14.832500  ...     260.630000        109.630722
# max         72.860000        42.000000  ...     597.970000       1490.000000
#
#        Number of periods  Mean period  Standard deviation of period  \
# count        1040.000000  1040.000000                    1040.00000
# mean          105.585513     0.007520                       0.00001
# std           146.890167     0.004202                       0.00031
# min             0.000000     0.000000                       0.00000
# 25%            41.000000     0.007520                       0.00000
# 50%            64.000000     0.010000                       0.00000
# 75%           106.000000     0.010000                       0.00000
# max          1489.000000     0.010000                       0.01000
#
#        Fraction of locally unvoiced frames  Number of voice breaks  \
# count                          1040.000000             1040.000000
# mean                             27.756796                1.109658
# std                              20.365575                1.534664
# min                               0.000000                0.000000
# 25%                               9.260000                0.000000
# 50%                              27.756796                1.000000
# 75%                              41.895000                1.109658
# max                              88.160000               12.000000
#
#        Degree of voice breaks  features 27        class
# count             1040.000000  1040.000000  1040.000000
# mean                12.550707    13.004036     0.500000
# std                 14.919936    15.523151     0.500241
# min                  0.000000     1.000000     0.000000
# 25%                  0.000000     1.000000     0.000000
# 50%                  7.615000     5.000000     0.500000
# 75%                 21.690000    23.000000     1.000000
# max                 69.120000    55.000000     1.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
x = df2.iloc[:, :-1].values
y = df2.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=12)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[114  16]
#  [ 24 106]]
# 0.8461538461538461
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[112  18]
#  [ 27 103]]
# 0.8269230769230769
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=7, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[114  16]
#  [ 26 104]]
# 0.8384615384615385
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=9, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[115  15]
#  [ 28 102]]
# 0.8346153846153846
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
