# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40, 50, 60, 70]

# Data akurasi
mean = [92.78, 91.24, 91.24, 90.72, 94.70, 94.33, 95.88]
median = [91.24, 90.21, 90.72, 90.21, 94.70, 94.85, 95.36]
data_asli = [80, 80, 70, 70, 88.89, 70, 90]
fuzzy_segitiga_k3 = [93.30, 92.78, 92.78, 92.78, 99.48, 94.85, 98.45]
fuzzy_segitiga_k5 = [95.36, 94.33, 94.85, 93.81, 99.48, 93.30, 97.42]
fuzzy_segitiga_k7 = [96.39, 96.39, 95.36, 96.39, 98.97, 94.85, 97.42]
fuzzy_segitiga_k9 = [96.39, 95.88, 95.88, 94.85, 99.48, 94.33, 98.45]
fuzzy_gaussian_k3 = [96.91, 94.33, 94.33, 93.81, 98.97, 95.88, 97.42]
fuzzy_gaussian_k5 = [96.91, 95.36, 95.88, 94.85, 99.48, 96.39, 98.45]
fuzzy_gaussian_k7 = [96.91, 96.91, 95.36, 95.36, 98.97, 96.39, 98.45]
fuzzy_gaussian_k9 = [97.42, 97.42, 95.88, 95.36, 99.48, 96.39, 97.94]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Audit Risk Dataset 10%')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN k=3', 'KNN k=5', 'KNN k=7', 'KNN k=9', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40]

# Data akurasi
mean = [91.49, 94.70, 94.33, 95.88]
median = [90.59, 94.70, 94.85, 95.36]
data_asli = [75, 88.89, 70, 90]
fuzzy_segitiga_k3 = [92.91, 99.48, 94.85, 98.45]
fuzzy_segitiga_k5 = [94.59, 99.48, 93.30, 97.42]
fuzzy_segitiga_k7 = [96.13, 98.97, 94.85, 97.42]
fuzzy_segitiga_k9 = [95.75, 99.48, 94.33, 98.45]
fuzzy_gaussian_k3 = [94.85, 98.97, 95.88, 97.42]
fuzzy_gaussian_k5 = [95.75, 99.48, 96.39, 98.45]
fuzzy_gaussian_k7 = [96.13, 98.97, 96.39, 98.45]
fuzzy_gaussian_k9 = [96.52, 99.48, 96.39, 97.94]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Audit Risk Dataset 10%')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()
