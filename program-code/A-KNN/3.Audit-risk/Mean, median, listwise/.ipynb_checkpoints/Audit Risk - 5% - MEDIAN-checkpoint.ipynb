# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("audit_5%.csv")

# %%
df
# Out:
#      Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  TOTAL  \
# 0            3.89    4.18      0.6   2.508    2.50      0.2   0.500   6.68
# 1             NaN    0.00      NaN   0.000    4.83      0.2   0.966   4.83
# 2            3.89    0.51      0.2   0.102    0.23      0.2   0.046   0.74
# 3            3.89    0.00      0.2     NaN   10.80      0.6   6.480    NaN
# 4            3.89    0.00      0.2   0.000    0.08      0.2   0.016   0.08
# ..            ...     ...      ...     ...     ...      ...     ...    ...
# 771           NaN    0.49      0.2   0.098    0.40      0.2   0.080   0.89
# 772         55.57    0.47      0.2   0.094    0.37      0.2   0.074   0.84
# 773         55.57    0.24      0.2     NaN    0.04      0.2   0.008   0.28
# 774         55.57    0.20      0.2   0.040    0.00      0.2   0.000   0.20
# 775         55.57    0.00      0.2   0.000    0.00      0.2     NaN   0.00
#
#      numbers  Score_B.1  ...  RiSk_E  History  Prob  Risk_F  Score  \
# 0        5.0        0.2  ...     NaN      0.0   0.2     0.0    2.4
# 1        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 2        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 3        6.0        0.6  ...     0.4      0.0   0.2     NaN    4.4
# 4        NaN        0.2  ...     0.4      NaN   NaN     0.0    2.0
# ..       ...        ...  ...     ...      ...   ...     ...    ...
# 771      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 772      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 773      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 774      NaN        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 775      5.0        0.2  ...     NaN      0.0   0.2     0.0    2.0
#
#      Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0            8.574           0.4             0.5         NaN   1.0
# 1            2.554           0.4             0.5      0.5108   0.0
# 2            1.548           0.4             0.5      0.3096   0.0
# 3           17.530           0.4             0.5      3.5060   1.0
# 4            1.416           0.4             0.5      0.2832   0.0
# ..             ...           ...             ...         ...   ...
# 771          1.578           0.4             NaN      0.3156   0.0
# 772          1.568           0.4             0.5      0.3136   0.0
# 773          1.456           0.4             0.5      0.2912   0.0
# 774          1.440           0.4             0.5      0.2880   0.0
# 775          1.464           0.4             0.5      0.2928   0.0
#
# [776 rows x 26 columns]

# %%
df.dtypes
# Out:
# Sector_score      float64
# PARA_A            float64
# Score_A           float64
# Risk_A            float64
# PARA_B            float64
# Score_B           float64
# Risk_B            float64
# TOTAL             float64
# numbers           float64
# Score_B.1         float64
# Risk_C            float64
# Money_Value       float64
# Score_MV          float64
# Risk_D            float64
# District_Loss     float64
# PROB              float64
# RiSk_E            float64
# History           float64
# Prob              float64
# Risk_F            float64
# Score             float64
# Inherent_Risk     float64
# CONTROL_RISK      float64
# Detection_Risk    float64
# Audit_Risk        float64
# Risk              float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Sector_score      56
# PARA_A            46
# Score_A           38
# Risk_A            46
# PARA_B            43
# Score_B           39
# Risk_B            46
# TOTAL             34
# numbers           38
# Score_B.1         26
# Risk_C            41
# Money_Value       43
# Score_MV          35
# Risk_D            35
# District_Loss     24
# PROB              45
# RiSk_E            48
# History           48
# Prob              43
# Risk_F            40
# Score             37
# Inherent_Risk     33
# CONTROL_RISK      35
# Detection_Risk    42
# Audit_Risk        49
# Risk               0
# dtype: int64

# %%
null_counts = df.isnull().sum()
null_percentages = 100 * null_counts / len(df)
null_percentages
# Out:
# Sector_score      7.216495
# PARA_A            5.927835
# Score_A           4.896907
# Risk_A            5.927835
# PARA_B            5.541237
# Score_B           5.025773
# Risk_B            5.927835
# TOTAL             4.381443
# numbers           4.896907
# Score_B.1         3.350515
# Risk_C            5.283505
# Money_Value       5.541237
# Score_MV          4.510309
# Risk_D            4.510309
# District_Loss     3.092784
# PROB              5.798969
# RiSk_E            6.185567
# History           6.185567
# Prob              5.541237
# Risk_F            5.154639
# Score             4.768041
# Inherent_Risk     4.252577
# CONTROL_RISK      4.510309
# Detection_Risk    5.412371
# Audit_Risk        6.314433
# Risk              0.000000
# dtype: float64

# %%
null_counts = df.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase hilang :",null_percentages)
# Out:
# total nilai : 20176
# nilai hilang : 1010
# persentase hilang : 5.005947660586836

# %% [markdown]
# # Imputasi Median

# %%
df2 = df.fillna(df.median())

# %%
df2
# Out:
#      Sector_score  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  TOTAL  \
# 0            3.89    4.18      0.6   2.508    2.50      0.2   0.500  6.680
# 1            3.89    0.00      0.2   0.000    4.83      0.2   0.966  4.830
# 2            3.89    0.51      0.2   0.102    0.23      0.2   0.046  0.740
# 3            3.89    0.00      0.2   0.175   10.80      0.6   6.480  1.365
# 4            3.89    0.00      0.2   0.000    0.08      0.2   0.016  0.080
# ..            ...     ...      ...     ...     ...      ...     ...    ...
# 771          3.89    0.49      0.2   0.098    0.40      0.2   0.080  0.890
# 772         55.57    0.47      0.2   0.094    0.37      0.2   0.074  0.840
# 773         55.57    0.24      0.2   0.175    0.04      0.2   0.008  0.280
# 774         55.57    0.20      0.2   0.040    0.00      0.2   0.000  0.200
# 775         55.57    0.00      0.2   0.000    0.00      0.2   0.078  0.000
#
#      numbers  Score_B.1  ...  RiSk_E  History  Prob  Risk_F  Score  \
# 0        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.4
# 1        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 2        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 3        6.0        0.6  ...     0.4      0.0   0.2     0.0    4.4
# 4        5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# ..       ...        ...  ...     ...      ...   ...     ...    ...
# 771      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 772      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 773      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 774      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
# 775      5.0        0.2  ...     0.4      0.0   0.2     0.0    2.0
#
#      Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0            8.574           0.4             0.5      0.5028   1.0
# 1            2.554           0.4             0.5      0.5108   0.0
# 2            1.548           0.4             0.5      0.3096   0.0
# 3           17.530           0.4             0.5      3.5060   1.0
# 4            1.416           0.4             0.5      0.2832   0.0
# ..             ...           ...             ...         ...   ...
# 771          1.578           0.4             0.5      0.3156   0.0
# 772          1.568           0.4             0.5      0.3136   0.0
# 773          1.456           0.4             0.5      0.2912   0.0
# 774          1.440           0.4             0.5      0.2880   0.0
# 775          1.464           0.4             0.5      0.2928   0.0
#
# [776 rows x 26 columns]

# %%
df2.describe()
# Out:
#        Sector_score      PARA_A     Score_A      Risk_A       PARA_B  \
# count    776.000000  776.000000  776.000000  776.000000   776.000000
# mean      19.021005    2.271612    0.344845    1.293624    10.281416
# std       23.810874    4.699168    0.172867    3.414958    49.849787
# min        1.850000    0.000000    0.200000    0.000000     0.000000
# 25%        2.370000    0.270000    0.200000    0.058000     0.000000
# 50%        3.890000    0.880000    0.200000    0.175000     0.410000
# 75%       55.570000    2.422500    0.600000    1.351500     2.845000
# max       59.850000   85.000000    0.600000   51.000000  1264.630000
#
#           Score_B      Risk_B        TOTAL     numbers   Score_B.1  ...  \
# count  776.000000  776.000000   776.000000  776.000000  776.000000  ...
# mean     0.308763    6.058462    12.718855    5.063789    0.222938  ...
# std      0.167949   30.000082    51.193382    0.258013    0.078959  ...
# min      0.200000    0.000000     0.000000    5.000000    0.200000  ...
# 25%      0.200000    0.000000     0.590000    5.000000    0.200000  ...
# 50%      0.200000    0.078000     1.365000    5.000000    0.200000  ...
# 75%      0.400000    0.966000     7.115000    5.000000    0.200000  ...
# max      0.600000  758.778000  1268.910000    9.000000    0.600000  ...
#
#            RiSk_E     History        Prob      Risk_F       Score  \
# count  776.000000  776.000000  776.000000  776.000000  776.000000
# mean     0.511340    0.100515    0.216495    0.052577    2.666753
# std      0.278568    0.528125    0.067670    0.305339    0.837278
# min      0.400000    0.000000    0.200000    0.000000    2.000000
# 25%      0.400000    0.000000    0.200000    0.000000    2.000000
# 50%      0.400000    0.000000    0.200000    0.000000    2.200000
# 75%      0.400000    0.000000    0.200000    0.000000    3.200000
# max      2.400000    9.000000    0.600000    5.400000    5.200000
#
#        Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk        Risk
# count     776.000000    776.000000           776.0  776.000000  776.000000
# mean       17.044519      0.565979             0.5    6.680907    0.393041
# std        54.527417      0.440384             0.0   38.267287    0.488741
# min         1.400000      0.400000             0.5    0.280000    0.000000
# 25%         1.590000      0.400000             0.5    0.319200    0.000000
# 50%         2.200000      0.400000             0.5    0.502800    0.000000
# 75%         8.991500      0.400000             0.5    2.692200    1.000000
# max       801.262000      5.800000             0.5  961.514400    1.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
x = df2.iloc[:, :-1].values
y = df2.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=32)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[104   3]
#  [ 11  76]]
# 0.9278350515463918
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[104   3]
#  [ 12  75]]
# 0.9226804123711341
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=7, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[105   2]
#  [ 14  73]]
# 0.9175257731958762
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=9, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[105   2]
#  [ 14  73]]
# 0.9175257731958762
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
