# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40, 50, 60, 70]

# Data akurasi
mean = [70.05, 70.59, 71.12, 73.80, 70.05, 71.66, 70.59]
median = [71.66, 70.59, 72.73, 73.26, 72.19, 71.66, 70.59]
data_asli = [66.67, 70.83, 72.92, 72.92, 66.67, 72.92, 74.31]
fuzzy_segitiga_k3 = [81.82, 82.35, 82.35, 82.89, 73.26, 79.14, 80.75]
fuzzy_segitiga_k5 = [80.75, 83.96, 82.89, 81.82, 76.47, 78.61, 83.96]
fuzzy_segitiga_k7 = [80.21, 82.35, 82.89, 81.28, 76.47, 78.61, 83.42]
fuzzy_segitiga_k9 = [80.21, 81.82, 81.82, 81.82, 77.54, 78.61, 81.28]
fuzzy_gaussian_k3 = [80.21, 83.42, 81.28, 79.68, 80.21, 78.61, 82.89]
fuzzy_gaussian_k5 = [80.21, 81.82, 80.21, 80.21, 73.80, 78.61, 80.75]
fuzzy_gaussian_k7 = [79.14, 80.75, 80.75, 80.21, 75.94, 78.61, 83.42]
fuzzy_gaussian_k9 = [80.75, 82.35, 82.35, 81.28, 72.73, 78.61, 80.75]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Blood Transfusion Dataset 5%')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN k=3', 'KNN k=5', 'KNN k=7', 'KNN k=9', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40]

# Data akurasi
mean = [71.39, 70.05, 71.66, 70.59]
median = [72.06, 72.19, 71.66, 70.59]
data_asli = [70.83, 66.67, 72.92, 74.31]
fuzzy_segitiga_k3 = [82.35, 73.26, 79.14, 80.75]
fuzzy_segitiga_k5 = [82.35, 76.47, 78.61, 83.96]
fuzzy_segitiga_k7 = [81.68, 76.47, 78.61, 83.42]
fuzzy_segitiga_k9 = [81.42, 77.54, 78.61, 81.28]
fuzzy_gaussian_k3 = [81.15, 80.21, 78.61, 82.89]
fuzzy_gaussian_k5 = [80.61, 73.80, 78.61, 80.75]
fuzzy_gaussian_k7 = [80.21, 75.94, 78.61, 83.42]
fuzzy_gaussian_k9 = [81.68, 72.73, 78.61, 80.75]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Blood Transfusion Dataset 5%')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()
