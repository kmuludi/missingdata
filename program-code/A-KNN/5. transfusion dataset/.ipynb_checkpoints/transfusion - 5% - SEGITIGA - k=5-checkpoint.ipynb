# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from scipy.spatial.distance import euclidean

# %%
df = pd.read_csv("transfusion.csv")

# %%
df
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                 2.0               50.0                12500.0
# 1                 0.0               13.0                 3250.0
# 2                 1.0               16.0                 4000.0
# 3                 2.0               20.0                 5000.0
# 4                 1.0               24.0                 6000.0
# ..                ...                ...                    ...
# 743              23.0                2.0                  500.0
# 744              21.0                2.0                  500.0
# 745              23.0                3.0                  750.0
# 746              39.0                1.0                  250.0
# 747              72.0                1.0                  250.0
#
#      Time (months)  whether he/she donated blood in March 2007
# 0             98.0                                         1.0
# 1             28.0                                         1.0
# 2             35.0                                         1.0
# 3             45.0                                         1.0
# 4             77.0                                         0.0
# ..             ...                                         ...
# 743           38.0                                         0.0
# 744           52.0                                         0.0
# 745           62.0                                         0.0
# 746           39.0                                         0.0
# 747           72.0                                         0.0
#
# [748 rows x 5 columns]

# %%
df.dtypes
# Out:
# Recency (months)                              float64
# Frequency (times)                             float64
# Monetary (c.c. blood)                         float64
# Time (months)                                 float64
# whether he/she donated blood in March 2007    float64
# dtype: object

# %%
total_values = df.iloc[:, :-1].size
total_values
# Out:
# 2992

# %%
values_to_drop = int(total_values * 0.0)
values_to_drop
# Out:
# 164

# %%
# Generate random indices for values to be dropped
drop_indices = np.random.choice(total_values, values_to_drop, replace=False)
dataset = df.iloc[:, :-1]

# Replace the selected values with NaN
dataset.values.flat[drop_indices] = np.nan

# %%
df
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                 2.0               50.0                12500.0
# 1                 0.0               13.0                 3250.0
# 2                 1.0               16.0                 4000.0
# 3                 2.0               20.0                 5000.0
# 4                 1.0               24.0                 6000.0
# ..                ...                ...                    ...
# 743              23.0                2.0                  500.0
# 744              21.0                2.0                  500.0
# 745              23.0                3.0                    NaN
# 746              39.0                NaN                  250.0
# 747              72.0                1.0                  250.0
#
#      Time (months)  whether he/she donated blood in March 2007
# 0             98.0                                         1.0
# 1             28.0                                         1.0
# 2             35.0                                         1.0
# 3             45.0                                         1.0
# 4             77.0                                         0.0
# ..             ...                                         ...
# 743            NaN                                         0.0
# 744           52.0                                         0.0
# 745           62.0                                         0.0
# 746           39.0                                         0.0
# 747           72.0                                         0.0
#
# [748 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Recency (months)                              46
# Frequency (times)                             42
# Monetary (c.c. blood)                         35
# Time (months)                                 41
# whether he/she donated blood in March 2007     0
# dtype: int64

# %%
null_counts = df.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase :",null_percentages)
# Out:
# total nilai : 3740
# nilai hilang : 164
# persentase : 4.385026737967914

# %%
null_counts = df.isnull().sum()
null_percentages = 100 * null_counts / len(df)
null_percentages
# Out:
# Recency (months)                              6.149733
# Frequency (times)                             5.614973
# Monetary (c.c. blood)                         4.679144
# Time (months)                                 5.481283
# whether he/she donated blood in March 2007    0.000000
# dtype: float64

# %% [markdown]
# # Imputasi

# %%
def jarak(df2,col):
    euc_dist[col] = []
    euc_dist_append =euc_dist[col].append
    for row in range(df2.shape[0]):
        current = df2.index[df2.iloc[:,col] == 0].tolist()
        current = current[0]
        a = df2.iloc[current,col+1:].tolist()
        b = df2.iloc[current,:col].tolist()
        x1 = b+a
        if(row is not current):
            a=df2.iloc[row,col+1:].tolist()
            b=df2.iloc[row,:col].tolist()
            x2=b+a
        else:
            continue
        dist = euclidean(x1,x2)
        euc_dist_append([dist,df2.iloc[row,col]])
#         print(" x1 = ",x1,"\n x2 = ",x2,"\n distance = ",dist)

    lst = list(euc_dist[col])
    lst.sort()
    euc_dist[col] = lst
#     print(euc_dist[col])

# %%
def Final(df,col,k):
    terdekat = []
    mean = 0
    minimum = None
    maximum = None
    fuzzy_val = []
    terdekat_append = terdekat.append
    fuzzy_append = fuzzy_val.append
    
    for val in range(k):
        terdekat_append(euc_dist[col][val])
    
    for x,y in terdekat:
        if (minimum is None or maximum is None):
            minimum = y
            maximum = y
        elif(y<minimum):
            minimum = y
        elif(y>maximum):
            maximum = y
        mean += y
    mean /= len(terdekat)
    print("min : ",minimum)
    print("max : ",maximum)
    print("mean : ",mean)
    for x,y in terdekat:
        fuzzy_append((y,fuzzy_triangular(y,minimum,mean,maximum)))

    print("fuzzy : ",fuzzy_val)
    pembilang = 0
    penyebut = 0
    y = 1
    for nilai,bobot in fuzzy_val:
        pembilang += nilai*bobot
        penyebut += bobot
        
        if (penyebut == 0):
            penyebut = y
            
    print("pembilang : ", pembilang)
    print("penyebut : ",penyebut)
    tertimbang = pembilang/penyebut
    print("rata-rata tertimbang : ",tertimbang)
    index = dummy.index[dummy.iloc[:,col] == 0].tolist()
    index = index[0]
    dummy.iloc[index,col] = tertimbang

# %%
def fuzzy_triangular(val, minimum, mean, maximum):
   if val <= minimum or val >= maximum: 
        return 0.0
   elif minimum < val <= mean:
        return float((val - minimum)/(mean - minimum)) 
   elif mean < val < maximum:
        return float((maximum - val)/(maximum - mean))

# %%
df2 = dataset.copy()
dummy = df2.fillna(0)
dummy
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)
# 0                 2.0               50.0                12500.0           98.0
# 1                 0.0               13.0                 3250.0           28.0
# 2                 1.0               16.0                 4000.0           35.0
# 3                 2.0               20.0                 5000.0           45.0
# 4                 1.0               24.0                 6000.0           77.0
# ..                ...                ...                    ...            ...
# 743              23.0                2.0                  500.0            0.0
# 744              21.0                2.0                  500.0           52.0
# 745              23.0                3.0                    0.0           62.0
# 746              39.0                0.0                  250.0           39.0
# 747              72.0                1.0                  250.0           72.0
#
# [748 rows x 4 columns]

# %%
euc_dist = {}

# %%
for i in range(df2.shape[1]):
    current = dummy.index[dummy.iloc[:,i] == 0].tolist()
    
    for x in current:
        jarak(dummy,i)
        Final(dummy,i,5)
dummy
# Out:
# min :  1.0
# max :  14.0
# mean :  4.6
# fuzzy :  [(2.0, 0.2777777777777778), (4.0, 0.8333333333333334), (1.0, 0.0), (2.0, 0.2777777777777778), (14.0, 0.0)]
# pembilang :  4.444444444444445
# penyebut :  1.3888888888888888
# rata-rata tertimbang :  3.2
# min :  4.0
# max :  11.0
# mean :  6.4
# fuzzy :  [(4.0, 0.0), (4.0, 0.0), (4.0, 0.0), (9.0, 0.4347826086956522), (11.0, 0.0)]
# pembilang :  3.91304347826087
# penyebut :  1.4347826086956523
# rata-rata tertimbang :  2.7272727272727275
# min :  0.0
# max :  4.0
# mean :  2.0
# fuzzy :  [(2.0, 1.0), (0.0, 0.0), (4.0, 0.0), (2.0, 1.0), (2.0, 1.0)]
# pembilang :  6.0
# penyebut :  3.0
# rata-rata tertimbang :  2.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2.0
# max :  4.0
# mean :  2.4
# fuzzy :  [(2.0, 0.0), (2.0, 0.0), (4.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  14.0
# max :  14.0
# mean :  14.0
# fuzzy :  [(14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0), (14.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  2250.0
# max :  3500.0
# mean :  2950.0
# fuzzy :  [(3500.0, 0.0), (3250.0, 0.45454545454545453), (2750.0, 0.7142857142857143), (3000.0, 0.9090909090909091), (2250.0, 0.0)]
# pembilang :  6168.831168831169
# penyebut :  3.077922077922078
# rata-rata tertimbang :  2004.2194092827003
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  1000.0
# max :  1250.0
# mean :  1150.0
# fuzzy :  [(1000.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1250.0, 0.0), (1000.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  28.0
# max :  98.0
# mean :  69.2
# fuzzy :  [(79.0, 0.6597222222222223), (28.0, 0.0), (77.0, 0.7291666666666667), (64.0, 0.8737864077669902), (98.0, 0.0)]
# pembilang :  164.18621898597627
# penyebut :  2.262675296655879
# rata-rata tertimbang :  72.56287246722289
# min :  0.0
# max :  87.0
# mean :  47.0
# fuzzy :  [(0.0, 0.0), (77.0, 0.25), (71.0, 0.4), (87.0, 0.0), (0.0, 0.0)]
# pembilang :  47.650000000000006
# penyebut :  1.65
# rata-rata tertimbang :  28.878787878787882
# min :  0.0
# max :  26.0
# mean :  13.8
# fuzzy :  [(0.0, 0.0), (11.0, 0.7971014492753623), (16.0, 0.819672131147541), (16.0, 0.819672131147541), (26.0, 0.0)]
# pembilang :  34.9976241387503
# penyebut :  3.4364457115704443
# rata-rata tertimbang :  10.184250553097344
# min :  10.184250553097344
# max :  26.0
# mean :  15.83685011061947
# fuzzy :  [(10.184250553097344, 0.0), (11.0, 0.1443140343838982), (16.0, 0.9839469169345809), (16.0, 0.9839469169345809), (26.0, 0.0)]
# pembilang :  33.07375572012947
# penyebut :  3.1122078682530603
# rata-rata tertimbang :  10.62710368979768
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
# min :  0.0
# max :  2.0
# mean :  1.6
# fuzzy :  [(0.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0), (2.0, 0.0)]
# pembilang :  0.0
# penyebut :  1.0
# rata-rata tertimbang :  0.0
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)
# 0                 2.0               50.0                12500.0           98.0
# 1                 3.2               13.0                 3250.0           28.0
# 2                 1.0               16.0                 4000.0           35.0
# 3                 2.0               20.0                 5000.0           45.0
# 4                 1.0               24.0                 6000.0           77.0
# ..                ...                ...                    ...            ...
# 743              23.0                2.0                  500.0            0.0
# 744              21.0                2.0                  500.0           52.0
# 745              23.0                3.0                    0.0           62.0
# 746              39.0                0.0                  250.0           39.0
# 747              72.0                1.0                  250.0           72.0
#
# [748 rows x 4 columns]

# %%
k = sum(dummy.iloc[:,i] == 0)
k
# Out:
# 37

# %%
dummy.describe()
# Out:
#        Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# count        748.000000         748.000000             748.000000
# mean           9.086850           5.216578            1319.518717
# std            8.209436           5.798134            1480.748855
# min            0.000000           0.000000               0.000000
# 25%            2.000000           1.000000             250.000000
# 50%            4.500000           3.000000             750.000000
# 75%           14.000000           7.000000            1750.000000
# max           74.000000          50.000000           12500.000000
#
#        Time (months)
# count     748.000000
# mean       32.353480
# std        24.826403
# min         0.000000
# 25%        14.000000
# 50%        26.500000
# 75%        47.250000
# max        98.000000

# %% [markdown]
# # Klasifikasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
x = dummy.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[125   7]
#  [ 44  11]]
# 0.7272727272727273
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[126   6]
#  [ 43  12]]
# 0.7379679144385026
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=7, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[125   7]
#  [ 45  10]]
# 0.7219251336898396
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=9, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[125   7]
#  [ 46   9]]
# 0.7165775401069518
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
classifier = KNeighborsClassifier(n_neighbors=11, metric='euclidean')
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print(cm)
print(accuracy)
# Out:
# [[130   2]
#  [ 50   5]]
# 0.7219251336898396
# C:\Users\User\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
