# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40, 50, 60, 70]

# Data akurasi
mean = [71.66, 70.59, 71.66, 69.52, 69.52, 70.59, 71.12]
median = [67.91, 70.59, 71.12,69.52, 67.91, 71.12, 71.12]
data_asli = [64.86, 69.37, 65.77, 63.96, 64.86, 74.77, 75.68]
fuzzy_segitiga_k3 = [84.49, 83.96, 80.75, 82.35, 78.07, 79.14, 85.56]
fuzzy_segitiga_k5 = [79.14, 82.35, 82.35, 81.28, 79.14, 77.54, 81.82]
fuzzy_segitiga_k7 = [80.21, 81.28, 79.68, 79.14, 74.33, 77.54, 80.21]
fuzzy_segitiga_k9 = [79.14, 81.82, 81.28, 81.28, 74.87, 77.54, 80.21]
fuzzy_gaussian_k3 = [82.89, 82.89, 81.82, 80.75, 73.26, 79.68, 86.10]
fuzzy_gaussian_k5 = [78.07, 81.82, 81.82, 81.82, 71.12, 79.14, 81.82]
fuzzy_gaussian_k7 = [79.14, 79.68, 80.75, 77.01, 75.94, 77.54, 78.61]
fuzzy_gaussian_k9 = [79.14, 81.28, 79.14, 78.07, 74.87, 77.01, 79.14]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Blood Transfusion Dataset 10%')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN k=3', 'KNN k=5', 'KNN k=7', 'KNN k=9', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40]

# Data akurasi
mean = [70.86, 69.52, 70.59, 71.12]
median = [69.79, 67.91, 71.12, 71.12]
data_asli = [65.99, 64.86, 74.77, 75.68]
fuzzy_segitiga_k3 = [82.89, 78.07, 79.14, 85.56]
fuzzy_segitiga_k5 = [81.28, 79.14, 77.54, 81.82]
fuzzy_segitiga_k7 = [80.08, 74.33, 77.54, 80.21]
fuzzy_segitiga_k9 = [80.88, 74.87, 77.54, 80.21]
fuzzy_gaussian_k3 = [82.09, 73.26, 79.68, 86.10]
fuzzy_gaussian_k5 = [80.88, 71.12, 79.14, 81.82]
fuzzy_gaussian_k7 = [79.14, 75.94, 77.54, 78.61]
fuzzy_gaussian_k9 = [79.41, 74.87, 77.01, 79.14]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Blood Transfusion Dataset 10%')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()
