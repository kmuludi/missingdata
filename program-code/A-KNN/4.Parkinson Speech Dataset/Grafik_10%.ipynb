# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40, 50, 60, 70]

# Data akurasi
mean = [82.69, 79.62, 83.08, 83.85, 95.77, 83.27, 90]
median = [82.69, 83.85, 84.62, 85, 94.62, 86.92, 91.92]
data_asli = [75, 68.75, 62.50, 75, 82.31, 81.67, 81.79]
fuzzy_segitiga_k3 = [90.77, 92.69, 91.54, 93.46, 96.54, 89.62, 96.15]
fuzzy_segitiga_k5 = [90.77, 91.92, 92.31, 91.54, 96.15, 85, 94.62]
fuzzy_segitiga_k7 = [90.38, 91.92, 92.31, 92.31, 94.23, 83.08, 91.92]
fuzzy_segitiga_k9 = [91.92, 91.54, 90.38, 88.46, 95.77, 81.15, 94.62]
fuzzy_gaussian_k3 = [89.23, 91.15, 91.15, 90.77, 96.15, 81.92, 95]
fuzzy_gaussian_k5 = [88.46, 90, 88.85, 90.38, 95.38, 81.54, 92.31]
fuzzy_gaussian_k7 = [91.15, 90, 90.38, 90.38, 95, 85.38, 93.08]
fuzzy_gaussian_k9 = [93.08, 90.38, 89.23, 90.77, 94.62, 86.54, 93.85]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Parkinson Speech Dataset 10%')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN k=3', 'KNN k=5', 'KNN k=7', 'KNN k=9', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40]

# Data akurasi
mean = [82.31, 95.77, 83.27, 90]
median = [84.04, 94.62, 86.92, 91.92]
data_asli = [70.31, 82.31, 81.67, 81.79]
fuzzy_segitiga_k3 = [92.12, 96.54, 89.62, 96.15]
fuzzy_segitiga_k5 = [91.63, 96.15, 85, 94.62]
fuzzy_segitiga_k7 = [91.73, 94.23, 83.08, 91.92]
fuzzy_segitiga_k9 = [90.58, 95.77, 81.15, 94.62]
fuzzy_gaussian_k3 = [90.58, 96.15, 81.92, 95]
fuzzy_gaussian_k5 = [89.42, 95.38, 81.54, 92.31]
fuzzy_gaussian_k7 = [90.48, 95, 85.38, 93.08]
fuzzy_gaussian_k9 = [90.87, 94.62, 86.54, 93.85]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Parkinson Speech Dataset 10%')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()
