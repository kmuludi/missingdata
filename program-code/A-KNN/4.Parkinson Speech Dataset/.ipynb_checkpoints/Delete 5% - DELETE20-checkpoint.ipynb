# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train_data.csv")

# %%
df
# Out:
#       Subject ID  Jitter (local)  Jitter (local, absolute)  Jitter (rap)  \
# 0            1.0            1.49                       0.0          0.90
# 1            1.0            0.73                       0.0          0.35
# 2            1.0            1.22                       0.0          0.73
# 3            1.0            2.50                       0.0          1.16
# 4            1.0            3.51                       0.0          1.72
# ...          ...             ...                       ...           ...
# 1030        40.0            4.34                       0.0          1.92
# 1031        40.0            7.04                       0.0          3.07
# 1032        40.0            2.00                       0.0          0.87
# 1033        40.0            5.00                       0.0          2.64
# 1034        40.0            1.92                       0.0          0.59
#
#       Jitter (ppq5)  Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  \
# 0              0.79          2.70             8.33                 0.78
# 1              0.38          1.06             5.86                 0.64
# 2              0.67          2.20             8.72                 0.88
# 3              1.63          3.47            13.51                 1.27
# 4              1.54          5.15             9.11                 1.04
# ...             ...           ...              ...                  ...
# 1030           2.29          5.77            13.00                 1.33
# 1031           2.80          9.21            19.95                 1.67
# 1032           0.88          2.62            14.29                 1.25
# 1033           2.11          7.93            13.25                 1.25
# 1034           0.85          1.77            14.42                 1.41
#
#       Shimmer (apq3)  Shimmer (apq5)  ...  Maximum pitch  Number of pulses  \
# 0               4.52            4.61  ...         187.58             160.0
# 1               2.06            3.18  ...         234.51             170.0
# 2               4.35            5.17  ...         211.44            1431.0
# 3               5.26            8.77  ...         220.23              94.0
# 4               3.10            4.93  ...         225.16             117.0
# ...              ...             ...  ...            ...               ...
# 1030            5.47            8.70  ...         207.65             246.0
# 1031           10.60           14.70  ...         178.37              45.0
# 1032            6.73            7.87  ...         142.99              54.0
# 1033            6.80            7.20  ...         142.99              56.0
# 1034            5.30            7.77  ...         152.73              65.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 0                 159.0         0.01                           0.0
# 1                 169.0         0.01                           0.0
# 2                1427.0         0.01                           0.0
# 3                  92.0         0.00                           0.0
# 4                 114.0         0.00                           0.0
# ...                 ...          ...                           ...
# 1030              238.0         0.01                           0.0
# 1031               42.0         0.01                           0.0
# 1032               53.0         0.01                           0.0
# 1033               52.0         0.01                           0.0
# 1034               63.0         0.01                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                    0.00                     0.0
# 1                                    2.25                     0.0
# 2                                   10.66                     1.0
# 3                                    0.00                     0.0
# 4                                   18.18                     1.0
# ...                                   ...                     ...
# 1030                                34.43                     5.0
# 1031                                13.51                     1.0
# 1032                                13.46                     0.0
# 1033                                25.81                     1.0
# 1034                                 5.77                     1.0
#
#       Degree of voice breaks  UPDRS  class
# 0                       0.00   23.0    1.0
# 1                       0.00   23.0    1.0
# 2                       0.18   23.0    1.0
# 3                       0.00   23.0    1.0
# 4                      13.32   23.0    1.0
# ...                      ...    ...    ...
# 1030                   34.51    1.0    0.0
# 1031                    8.92    1.0    0.0
# 1032                    0.00    1.0    0.0
# 1033                   13.72    1.0    0.0
# 1034                    4.10    1.0    0.0
#
# [1035 rows x 29 columns]

# %%
df.drop('Subject ID', axis=1, inplace=True)
df
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0          0.90           0.79
# 1               0.73                       0.0          0.35           0.38
# 2               1.22                       0.0          0.73           0.67
# 3               2.50                       0.0          1.16           1.63
# 4               3.51                       0.0          1.72           1.54
# ...              ...                       ...           ...            ...
# 1030            4.34                       0.0          1.92           2.29
# 1031            7.04                       0.0          3.07           2.80
# 1032            2.00                       0.0          0.87           0.88
# 1033            5.00                       0.0          2.64           2.11
# 1034            1.92                       0.0          0.59           0.85
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 0             2.70             8.33                 0.78            4.52
# 1             1.06             5.86                 0.64            2.06
# 2             2.20             8.72                 0.88            4.35
# 3             3.47            13.51                 1.27            5.26
# 4             5.15             9.11                 1.04            3.10
# ...            ...              ...                  ...             ...
# 1030          5.77            13.00                 1.33            5.47
# 1031          9.21            19.95                 1.67           10.60
# 1032          2.62            14.29                 1.25            6.73
# 1033          7.93            13.25                 1.25            6.80
# 1034          1.77            14.42                 1.41            5.30
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 0               4.61             6.80  ...         187.58             160.0
# 1               3.18             7.19  ...         234.51             170.0
# 2               5.17             7.55  ...         211.44            1431.0
# 3               8.77            16.78  ...         220.23              94.0
# 4               4.93            12.82  ...         225.16             117.0
# ...              ...              ...  ...            ...               ...
# 1030            8.70            14.45  ...         207.65             246.0
# 1031           14.70            22.38  ...         178.37              45.0
# 1032            7.87            13.80  ...         142.99              54.0
# 1033            7.20            10.83  ...         142.99              56.0
# 1034            7.77            19.07  ...         152.73              65.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 0                 159.0         0.01                           0.0
# 1                 169.0         0.01                           0.0
# 2                1427.0         0.01                           0.0
# 3                  92.0         0.00                           0.0
# 4                 114.0         0.00                           0.0
# ...                 ...          ...                           ...
# 1030              238.0         0.01                           0.0
# 1031               42.0         0.01                           0.0
# 1032               53.0         0.01                           0.0
# 1033               52.0         0.01                           0.0
# 1034               63.0         0.01                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                    0.00                     0.0
# 1                                    2.25                     0.0
# 2                                   10.66                     1.0
# 3                                    0.00                     0.0
# 4                                   18.18                     1.0
# ...                                   ...                     ...
# 1030                                34.43                     5.0
# 1031                                13.51                     1.0
# 1032                                13.46                     0.0
# 1033                                25.81                     1.0
# 1034                                 5.77                     1.0
#
#       Degree of voice breaks  UPDRS  class
# 0                       0.00   23.0    1.0
# 1                       0.00   23.0    1.0
# 2                       0.18   23.0    1.0
# 3                       0.00   23.0    1.0
# 4                      13.32   23.0    1.0
# ...                      ...    ...    ...
# 1030                   34.51    1.0    0.0
# 1031                    8.92    1.0    0.0
# 1032                    0.00    1.0    0.0
# 1033                   13.72    1.0    0.0
# 1034                    4.10    1.0    0.0
#
# [1035 rows x 28 columns]

# %%
pct_missing = 0.05186
num_missing = int(df.iloc[:, :-1].size * pct_missing)
num_missing
# Out:
# 1449

# %%
df.iloc[:, :-1].size
# Out:
# 27945

# %%
idx = np.random.choice(df.iloc[:, :-1].size, num_missing, replace=False)

# %%
dataset = df.astype(float)
dataset.iloc[:, :-1].values.flat[idx] = np.nan

# %%
df
# Out:
#       Jitter (local)  Jitter (local, absolute)  Jitter (rap)  Jitter (ppq5)  \
# 0               1.49                       0.0          0.90           0.79
# 1               0.73                       0.0          0.35           0.38
# 2               1.22                       0.0          0.73           0.67
# 3               2.50                       0.0          1.16           1.63
# 4               3.51                       0.0          1.72           1.54
# ...              ...                       ...           ...            ...
# 1030            4.34                       0.0          1.92           2.29
# 1031            7.04                       0.0          3.07           2.80
# 1032            2.00                       0.0          0.87           0.88
# 1033            5.00                       0.0          2.64           2.11
# 1034            1.92                       0.0          0.59           0.85
#
#       Jitter (ddp)  Shimmer (local)  Shimmer (local, dB)  Shimmer (apq3)  \
# 0             2.70             8.33                 0.78            4.52
# 1             1.06             5.86                 0.64            2.06
# 2             2.20             8.72                 0.88            4.35
# 3             3.47            13.51                 1.27            5.26
# 4             5.15             9.11                 1.04            3.10
# ...            ...              ...                  ...             ...
# 1030          5.77            13.00                 1.33            5.47
# 1031          9.21            19.95                 1.67           10.60
# 1032          2.62            14.29                 1.25            6.73
# 1033          7.93            13.25                 1.25            6.80
# 1034          1.77            14.42                 1.41            5.30
#
#       Shimmer (apq5)  Shimmer (apq11)  ...  Maximum pitch  Number of pulses  \
# 0               4.61             6.80  ...         187.58             160.0
# 1               3.18             7.19  ...         234.51             170.0
# 2               5.17             7.55  ...         211.44            1431.0
# 3               8.77            16.78  ...         220.23              94.0
# 4               4.93            12.82  ...         225.16             117.0
# ...              ...              ...  ...            ...               ...
# 1030            8.70            14.45  ...         207.65             246.0
# 1031           14.70            22.38  ...         178.37              45.0
# 1032            7.87            13.80  ...         142.99              54.0
# 1033            7.20            10.83  ...         142.99              56.0
# 1034            7.77            19.07  ...         152.73              65.0
#
#       Number of periods  Mean period  Standard deviation of period  \
# 0                 159.0         0.01                           0.0
# 1                 169.0         0.01                           0.0
# 2                1427.0         0.01                           0.0
# 3                  92.0         0.00                           0.0
# 4                 114.0         0.00                           0.0
# ...                 ...          ...                           ...
# 1030              238.0         0.01                           0.0
# 1031               42.0         0.01                           0.0
# 1032               53.0         0.01                           0.0
# 1033               52.0         0.01                           0.0
# 1034               63.0         0.01                           0.0
#
#       Fraction of locally unvoiced frames  Number of voice breaks  \
# 0                                    0.00                     0.0
# 1                                    2.25                     0.0
# 2                                   10.66                     1.0
# 3                                    0.00                     0.0
# 4                                   18.18                     1.0
# ...                                   ...                     ...
# 1030                                34.43                     5.0
# 1031                                13.51                     1.0
# 1032                                13.46                     0.0
# 1033                                25.81                     1.0
# 1034                                 5.77                     1.0
#
#       Degree of voice breaks  UPDRS  class
# 0                       0.00   23.0    1.0
# 1                       0.00   23.0    1.0
# 2                       0.18   23.0    1.0
# 3                       0.00   23.0    1.0
# 4                      13.32   23.0    1.0
# ...                      ...    ...    ...
# 1030                   34.51    1.0    0.0
# 1031                    8.92    1.0    0.0
# 1032                    0.00    1.0    0.0
# 1033                   13.72    1.0    0.0
# 1034                    4.10    1.0    0.0
#
# [1035 rows x 28 columns]

# %%
dataset.dtypes
# Out:
# Jitter (local)                         float64
# Jitter (local, absolute)               float64
# Jitter (rap)                           float64
# Jitter (ppq5)                          float64
# Jitter (ddp)                           float64
# Shimmer (local)                        float64
# Shimmer (local, dB)                    float64
# Shimmer (apq3)                         float64
# Shimmer (apq5)                         float64
# Shimmer (apq11)                        float64
# Shimmer (dda)                          float64
# AC                                     float64
# NTH                                    float64
# HTN                                    float64
# Median pitch                           float64
# Mean pitch                             float64
# Standard deviation                     float64
# Minimum pitch                          float64
# Maximum pitch                          float64
# Number of pulses                       float64
# Number of periods                      float64
# Mean period                            float64
# Standard deviation of period           float64
# Fraction of locally unvoiced frames    float64
# Number of voice breaks                 float64
# Degree of voice breaks                 float64
# UPDRS                                  float64
# class                                  float64
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# Jitter (local)                         48
# Jitter (local, absolute)               56
# Jitter (rap)                           51
# Jitter (ppq5)                          55
# Jitter (ddp)                           57
# Shimmer (local)                        55
# Shimmer (local, dB)                    52
# Shimmer (apq3)                         53
# Shimmer (apq5)                         48
# Shimmer (apq11)                        60
# Shimmer (dda)                          48
# AC                                     47
# NTH                                    56
# HTN                                    47
# Median pitch                           64
# Mean pitch                             37
# Standard deviation                     57
# Minimum pitch                          47
# Maximum pitch                          50
# Number of pulses                       54
# Number of periods                      63
# Mean period                            65
# Standard deviation of period           52
# Fraction of locally unvoiced frames    57
# Number of voice breaks                 52
# Degree of voice breaks                 62
# UPDRS                                  56
# class                                   0
# dtype: int64

# %%
null_counts = dataset.isnull().sum()
null_percentages = null_counts / len(dataset)
null_percentages
# Out:
# Jitter (local)                         0.046377
# Jitter (local, absolute)               0.054106
# Jitter (rap)                           0.049275
# Jitter (ppq5)                          0.053140
# Jitter (ddp)                           0.055072
# Shimmer (local)                        0.053140
# Shimmer (local, dB)                    0.050242
# Shimmer (apq3)                         0.051208
# Shimmer (apq5)                         0.046377
# Shimmer (apq11)                        0.057971
# Shimmer (dda)                          0.046377
# AC                                     0.045411
# NTH                                    0.054106
# HTN                                    0.045411
# Median pitch                           0.061836
# Mean pitch                             0.035749
# Standard deviation                     0.055072
# Minimum pitch                          0.045411
# Maximum pitch                          0.048309
# Number of pulses                       0.052174
# Number of periods                      0.060870
# Mean period                            0.062802
# Standard deviation of period           0.050242
# Fraction of locally unvoiced frames    0.055072
# Number of voice breaks                 0.050242
# Degree of voice breaks                 0.059903
# UPDRS                                  0.054106
# class                                  0.000000
# dtype: float64

# %%
null_counts = dataset.isnull().sum().sum()
total = df.size
null_percentages = 100 * null_counts / total
print("total nilai :",total)
print("nilai hilang :",null_counts)
print("persentase :",null_percentages)
# Out:
# total nilai : 28980
# nilai hilang : 1449
# persentase : 5.0

# %%
dataset.to_csv('Parkinson_5%.csv', index=False)
