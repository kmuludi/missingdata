# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40, 50, 60, 70]

# Data akurasi
mean = [84.62, 82.69, 83.85, 83.46, 92.31, 86.44, 89.23]
median = [85.00, 80.77, 81.92, 81.92, 92.40, 90.58, 92.31]
data_asli = [75, 78.33, 78.33, 80, 82.31, 81.67, 81.79]
fuzzy_segitiga_k3 = [94.23, 93.85, 92.31, 92.31, 96.54, 89.62, 96.15]
fuzzy_segitiga_k5 = [93.08, 93.85, 94.23, 93.46, 96.15, 85, 94.62]
fuzzy_segitiga_k7 = [93.08, 93.08, 92.31, 92.69, 94.23, 83.08, 91.92]
fuzzy_segitiga_k9 = [93.08, 93.46, 94.23, 93.08, 95.77, 81.15, 94.62]
fuzzy_gaussian_k3 = [93.46, 91.92, 91.54, 92.69, 96.15, 81.92, 95]
fuzzy_gaussian_k5 = [91.54, 93.08, 91.54, 90.77, 95.38, 81.54, 92.31]
fuzzy_gaussian_k7 = [92.69, 94.23, 91.15, 91.54, 95, 85.38, 93.08]
fuzzy_gaussian_k9 = [91.54, 93.08, 92.31, 91.92, 94.62, 86.54, 93.85]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Parkinson Speech Dataset 5%')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN k=3', 'KNN k=5', 'KNN k=7', 'KNN k=9', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40]

# Data akurasi
mean = [83.65, 92.31, 86.44, 89.23]
median = [82.40, 92.40, 90.58, 92.31]
data_asli = [77.92, 82.31, 81.67, 81.79]
fuzzy_segitiga_k3 = [93.17, 96.54, 89.62, 96.15]
fuzzy_segitiga_k5 = [93.65, 96.15, 85, 94.62]
fuzzy_segitiga_k7 = [92.79, 94.23, 83.08, 91.92]
fuzzy_segitiga_k9 = [93.46, 95.77, 81.15, 94.62]
fuzzy_gaussian_k3 = [92.40, 96.15, 81.92, 95]
fuzzy_gaussian_k5 = [91.73, 95.38, 81.54, 92.31]
fuzzy_gaussian_k7 = [92.40, 95, 85.38, 93.08]
fuzzy_gaussian_k9 = [92.21, 94.62, 86.54, 93.85]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Parkinson Speech Dataset 5%')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()
