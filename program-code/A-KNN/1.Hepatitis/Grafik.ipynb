# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40, 50, 60, 70]

# Data akurasi
mean = [66.67, 71.79, 74.36, 74.36, 82.05, 64.10, 79.49]
median = [76.92, 69.23, 74.36, 74.36, 79.49, 64.10, 74.36]
data_asli = [65, 65,65, 65, 70, 55, 70]
fuzzy_segitiga_k3 = [94.87, 97.44, 97.44, 97.44, 96.77, 86.45, 89.03]
fuzzy_segitiga_k5 = [92.31, 94.87, 97.44, 97.44, 97.42, 88.39, 90.97]
fuzzy_segitiga_k7 = [97.44, 97.44, 97.44, 97.44, 96.13, 88.39, 92.90]
fuzzy_segitiga_k9 = [97.44, 97.44, 97.44, 97.44, 96.77, 88.39, 90.32]
fuzzy_gaussian_k3 = [84.62, 87.18, 84.62, 84.62, 89.74, 74.36, 82.05]
fuzzy_gaussian_k5 = [84.62, 87.18, 87.18, 82.05, 89.74, 76.92, 84.62]
fuzzy_gaussian_k7 = [84.62, 87.18, 84.62, 84.62, 84.62, 76.92, 82.05]
fuzzy_gaussian_k9 = [84.62, 87.18, 87.18, 84.62, 84.62, 76.92, 79.49]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Hepatitis Dataset')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN k=3', 'KNN k=5', 'KNN k=7', 'KNN k=9', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40]

# Data akurasi
mean = [71.79, 82.05, 64.10, 79.49]
median = [73.72, 79.49, 64.10, 74.36]
data_asli = [65, 70, 55, 70]
fuzzy_segitiga_k3 = [96.79, 96.77, 86.45, 89.03]
fuzzy_segitiga_k5 = [95.51, 97.42, 88.39, 90.97]
fuzzy_segitiga_k7 = [97.44, 96.13, 88.39, 92.90]
fuzzy_segitiga_k9 = [97.44, 96.77, 88.39, 90.32]
fuzzy_gaussian_k3 = [85.26, 89.74, 74.36, 82.05]
fuzzy_gaussian_k5 = [85.26, 89.74, 76.92, 84.62]
fuzzy_gaussian_k7 = [85.26, 84.62, 76.92, 82.05]
fuzzy_gaussian_k9 = [85.90, 84.62, 76.92, 79.49]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Hepatitis Dataset')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()
