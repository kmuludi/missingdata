# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40, 50, 60, 70]

# Data akurasi
mean = [93.82, 93.09, 92.73, 92.73, 92.73, 75.27, 92.36]
median = [93.82, 93.09, 92.73, 92.73, 92.73, 75.64, 92.73]
data_asli = [92.13, 92.59, 92.59, 92.59, 90.74, 72.22, 89.35]
fuzzy_segitiga_k3 = [96.69, 97.16, 97, 97, 97.16, 70.19, 97]
fuzzy_segitiga_k5 = [96.53, 97.32, 96.85, 97, 96.69, 69.87, 96.69]
fuzzy_segitiga_k7 = [97.32, 97.95, 98.11, 98.11, 97, 68.77, 97]
fuzzy_segitiga_k9 = [96.53, 96.85, 96.69, 96.69, 97.16, 68.77, 97]
fuzzy_gaussian_k3 = [97, 97.48, 96.69, 96.85, 95.90, 72.40, 96.85]
fuzzy_gaussian_k5 = [96.53, 97.48, 96.85, 96.85, 96.21, 73.77, 96.06]
fuzzy_gaussian_k7 = [96.37, 97.48, 96.85, 96.85, 96.21, 72.08, 96.06]
fuzzy_gaussian_k9 = [96.69, 97.48, 96.69, 96.85, 95.74, 69.24, 95.90]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Ozone Level Detection Dataset')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN k=3', 'KNN k=5', 'KNN k=7', 'KNN k=9', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 20, 30, 40]

# Data akurasi
mean = [93.09, 92.73, 75.27, 92.36]
median = [93.09, 92.73, 75.64, 92.73]
data_asli = [92.48, 90.74, 72.22, 89.35]
fuzzy_segitiga_k3 = [96.96, 97.16, 70.19, 97]
fuzzy_segitiga_k5 = [96.92, 96.69, 69.87, 96.69]
fuzzy_segitiga_k7 = [97.87, 97, 68.77, 97]
fuzzy_segitiga_k9 = [96.69, 97.16, 68.77, 97]
fuzzy_gaussian_k3 = [97, 95.90, 72.40, 96.85]
fuzzy_gaussian_k5 = [96.92, 96.21, 73.77, 96.06]
fuzzy_gaussian_k7 = [96.88, 96.21, 72.08, 96.06]
fuzzy_gaussian_k9 = [96.92, 95.74, 69.24, 95.90]

# Membuat grafik
plt.plot(persentase, mean, marker='o', label='Mean')
plt.plot(persentase, median, marker='o', label='Median')
plt.plot(persentase, data_asli, marker='o', label='Listwise Deletion')
plt.plot(persentase, fuzzy_segitiga_k3, marker='o', label='Triangular MF k=3')
plt.plot(persentase, fuzzy_segitiga_k5, marker='o', label='Triangular MF k=5')
plt.plot(persentase, fuzzy_segitiga_k7, marker='o', label='Triangular MF k=7')
plt.plot(persentase, fuzzy_segitiga_k9, marker='o', label='Triangular MF k=9')
plt.plot(persentase, fuzzy_gaussian_k3, marker='o', label='Gaussian MF k=3')
plt.plot(persentase, fuzzy_gaussian_k5, marker='o', label='Gaussian MF k=5')
plt.plot(persentase, fuzzy_gaussian_k7, marker='o', label='Gaussian MF k=7')
plt.plot(persentase, fuzzy_gaussian_k9, marker='o', label='Gaussian MF k=9')

# Mengatur label sumbu x dan y
plt.xlabel('Classification Methods')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Ozone Level Detection Dataset')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['KNN', 'DT', 'NB', 'NN'])

# Menampilkan grafik
plt.show()
