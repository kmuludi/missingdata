# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 80]

# Data akurasi
knn = [98.11, 97.48]
neural_network = [97, 96.85]
decision_tree = [97.16, 96.21]
naive_bayes = [70.19, 73.66]
neural_network_el = [90, 88]
decision_tree_el = [96, 92]
naive_bayes_el = [73, 69]


# Membuat grafik
plt.plot(persentase, knn, marker='o', label='KNN')
plt.plot(persentase, decision_tree, marker='o', label='Decision Tree')
plt.plot(persentase, neural_network, marker='o', label='Neural Network')
plt.plot(persentase, naive_bayes, marker='o', label='Naïve Bayes')
plt.plot(persentase, decision_tree_el, marker='o', label='Decision Tree by (El-Bakry et al., 2021)')
plt.plot(persentase, neural_network_el, marker='o', label='NN by (El-Bakry et al., 2021)')
plt.plot(persentase, naive_bayes_el, marker='o', label='Naïve Bayes by (El-Bakry et al., 2021)')

# Mengatur label sumbu x dan y
# plt.xlabel('Klasifikasi KNN')
plt.ylabel('Percentage Accuracy')

# Mengatur judul grafik
plt.title('Ozone Level Detection Dataset')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['Triangular MF', 'Gaussian MF'])

# Mengatur rentang sumbu x dan y
# plt.xlim(0, 40)
plt.ylim(60, 100)

# Menampilkan grafik
plt.show()

# %%
import matplotlib.pyplot as plt

# Persentase akurasi
persentase = [10, 80]

# Data akurasi
knn = [98.11, 97.48]
neural_network = [90, 88]
decision_tree = [96, 92]
naive_bayes = [73, 69]


# Membuat grafik
plt.plot(persentase, knn, marker='o', label='KNN pada penelitian ini')
plt.plot(persentase, neural_network, marker='o', label='NN oleh (El-Bakry et al., 2021)')
plt.plot(persentase, decision_tree, marker='o', label='Decision Tree oleh (El-Bakry et al., 2021)')
plt.plot(persentase, naive_bayes, marker='o', label='Naïve Bayes oleh (El-Bakry et al., 2021)')

# Mengatur label sumbu x dan y
# plt.xlabel('Klasifikasi KNN')
plt.ylabel('Persentase Akurasi')

# Mengatur judul grafik
plt.title('Ozone Level Detection Dataset')

# Menambahkan legenda
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', fontsize='small')

# Menambahkan label pada sumbu x
plt.xticks(persentase, ['Fuzzy segitiga', 'Fuzzy Gaussian'])

# Mengatur rentang sumbu x dan y
# plt.xlim(0, 40)
plt.ylim(60, 100)

# Menampilkan grafik
plt.show()
